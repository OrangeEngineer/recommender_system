# %% [markdown]
# ## Data Exploration
#
# From the task. Three raw datasets have been provided in order to create recommender system which are
#
#  - user_applications
#  - previous_job_post
#  - and active_job_post

# %%
import pandas as pd
from IPython.display import display

user = pd.read_csv("user_applications.csv")
previous = pd.read_csv("previous_job_post.csv")
active = pd.read_csv("active_job_post.csv")

display(user.head())
display(previous.head())
display(active.head())
# Out:
#    user_id  job_id
# 0     1951    7662
# 1     4517   12970
# 2     4469   12662
# 3      502   14356
# 4     1620   23126
#    job_id                                          job_title  \
# 0       0                     Warehouse & Distribution Sales
# 1       1  เจ้าหน้าที่บรรณาธิการหนังสือเรียน กลุ่มสาระสัง...
# 2       2   Education Consultant ประจำสาขา เซ็นทรัลแจ้งวัฒนะ
# 3       3  ★★เริ่มงาน 25 ม.ค.นี้  (ฝ่ายขายประจำOffice รับ...
# 4       4          ผู้จัดการอาคาร (ใกล้ ม.ธรรมศาสตร์ รังสิต)
#
#                                  role_name  \
# 0                                      ขาย
# 1           นักเขียน/บรรณาธิการ/นักแปลภาษา
# 2                                      ขาย
# 3  บริการลูกค้า/ลูกค้าสัมพันธ์/Call Center
# 4             ผู้จัดการ/ผู้อำนวยการ/MD/CEO
#
#                              sub_role_name                   location  \
# 0                      พนักงานขาย/Sales/AE         อ.ศรีราชา จ.ชลบุรี
# 1                               บรรณาธิการ  กรุงเทพมหานคร(เขตบางซื่อ)
# 2                                 ขายอื่นๆ          นนทบุรี(ปากเกร็ด)
# 3  บริการ/ลูกค้าสัมพันธ์/Call Center อื่นๆ      กรุงเทพมหานคร(ทุกเขต)
# 4                          ผู้จัดการทั่วไป      อ.คลองหลวง จ.ปทุมธานี
#
#     latitude   longitude           salary company_name
# 0        NaN         NaN          ไม่ระบุ       vueoeo
# 1        NaN         NaN          ตามตกลง       30jfum
# 2        NaN         NaN    15,000-16,000       1d36pp
# 3        NaN         NaN    13,000-50,000       wqalnh
# 4  14.064528  100.609091  28,000 - 33,000       p1he99
#    job_id                                          job_title  \
# 0   25320                          พนักงานขับรถรับส่งพนักงาน
# 1   25321                       ผู้ประเมินราคางานตกแต่งภายใน
# 2   25322                   นักออกแบบกราฟิก (Graphic design)
# 3   25323  พนักงานขับรถส่งสินค้า ประจำศูนย์กระจายสินค้า ส...
# 4   25324                 พนักงานขายทางโทรศัพท์​ / Telesales
#
#                                   role_name                    sub_role_name  \
# 0                                   คนขับรถ                    คนขับรถ อื่นๆ
# 1  โยธา/สำรวจ/สถาปัตย์/มัณฑนากร/ประเมินราคา                      ประเมินราคา
# 2              ศิลปะ/กราฟฟิค/ออกแบบ/ช่างภาพ         Graphic Design/สิ่งพิมพ์
# 3                                   คนขับรถ                 คนขับรถส่งสินค้า
# 4                                       ขาย  พนักงานขายทางโทรศัพท์/Telesales
#
#                                             location   latitude  longitude  \
# 0  กรุงเทพมหานคร(เขตพระโขนง),กรุงเทพมหานคร(เขตสวน...        NaN        NaN
# 1                           อ.เมืองนนทบุรี จ.นนทบุรี  13.872826  100.53001
# 2                           เขตคลองสาน กรุงเทพมหานคร        NaN        NaN
# 3                         กรุงเทพมหานคร(เขตคันนายาว)        NaN        NaN
# 4                           เขตปทุมวัน กรุงเทพมหานคร        NaN        NaN
#
#                                 salary company_name
# 0                              ตามตกลง       83akmq
# 1  25,000-35,000 ขึ้นอยู่กับประสบการณ์       b57auw
# 2                    18,000-25,000 บาท       362uhk
# 3                        16,000-18,000       yp1i9y
# 4                  15,000 + คอมมิสชั่น       4s96ty

# %%
#Exploration for columns and values

print("-----user application------")
display(user.dtypes)

print("-----previous job post------")
display(previous.dtypes)

print("-----active job post------")
display(active.dtypes)
# Out:
# -----user application------
# user_id    int64
# job_id     int64
# dtype: object
# -----previous job post------
# job_id             int64
# job_title         object
# role_name         object
# sub_role_name     object
# location          object
# latitude         float64
# longitude        float64
# salary            object
# company_name      object
# dtype: object
# -----active job post------
# job_id             int64
# job_title         object
# role_name         object
# sub_role_name     object
# location          object
# latitude         float64
# longitude        float64
# salary            object
# company_name      object
# dtype: object

# %% [markdown]
# ## Data Cleaning and feature selection
#
# From data exploration, I choose 4 attributes to use in a feature space as following;
#
# - role_name -> role_name, unlike job_title, can be easily clean and turn into catagorical dataset. This is because role_name contain short and meaningful words each row.
# - sub_role_name -> the same reason as role_name
# - location -> It will not be used directly. Instead, this attribute could be extracted and use their information which is province.
# - company_name -> company_name can be easily clean and turn into catagorical dataset. It usually is one of the reason for job application.
#
# Firstly, all attributes have to translate into English. This is because English language is easy for data cleaning than Thai langauge (Complexity of Language, Library for NLP Application, etc.). Google translator libs is called for this work.

# %%
from google_trans_new import google_translator

def translation(df):
    translator = google_translator()
    unique_elements = df.unique()
    translations = {}

    for element in sorted(unique_elements):
        # add translation to the dictionary
        translation = translator.translate(element, lang_tgt='en')
        print(element + " -> " + translation)
        translations[element] = translation

    print(translations)
    return translations

# %%
active.dropna(subset=['role_name','sub_role_name'], inplace=True)
previous.dropna(subset=['role_name','sub_role_name'], inplace=True)

active_translations = translation(active['role_name'])
previous_translations = translation(previous['role_name'])

active['role_name'].replace(active_translations, inplace=True)
previous['role_name'].replace(previous_translations, inplace=True)

display(active.head())
display(previous.head())
# Out:
# E-commerce -> E-commerce
# Freelance -> Freelance
# Part-time/พนักงานสัญญาจ้าง -> Part-time employment contract
# กฎหมาย -> law
# การตลาด -> Marketing
# การตลาด / PR -> Marketing / PR
# การผลิต / QA&QC -> Production / QA & QC
# การศึกษา/ วิชาการ -> Education / Academic
# การแพทย์ -> Medical
# ก่อสร้าง -> Construction
# ขนส่ง/คลังสินค้า -> Transport / Warehouse
# ขนส่งและคลังสินค้า -> Transport and warehouse
# ขับรถ -> Drive
# ขาย -> sell
# คนขับรถ -> Drivers
# คลังสินค้า -> warehouse
# ความสะอาดและสวน -> Cleanliness and garden
# คอมพิวเตอร์/IT/โปรแกรมเมอร์ -> Computer / IT / Programmer
# งาน Part-time/พนักงานชั่วคราว -> Part-time work / temporary employees
# งานการตลาด งาน PR -> Marketing Jobs PR
# งานการผลิต -> Production work
# งานการเงิน-ธนาคาร -> Finance - Bank
# งานขนส่ง -> Transportation
# งานขนส่ง-คลังสินค้า -> Transportation - Warehouse
# งานขาย งานบริการลูกค้า งานพัฒนาธุรกิจ -> Customer service sales Business development
# งานจัดซื้อ -> Purchasing
# งานธนาคาร งานการเงิน -> Banking Banking
# งานธุรการ งานทรัพยากรบุคคล -> Human Resources Administration
# งานนำเข้า-ส่งออก -> Import-export
# งานบริการด้านการแพทย์ -> Medical Services
# งานบริการลูกค้า-Call Center -> Customer Service-Call Center
# งานบริการเฉพาะทาง -> Specialized services
# งานบริหาร -> Management
# งานบัญชี -> Accounting
# งานวิทยาศาสตร์ งาน Lab งานวิจัยและพัฒนา -> Science, Lab, Research and Development
# งานวิศวกรรม -> Engineering
# งานสุขภาพ งานโภชนาการ งานความงาม -> Health jobs, nutrition, beauty
# งานอสังหาริมทรัพย์ -> Real estate
# งานออกแบบ -> Design
# งานอีคอมเมิร์ซ -> Ecommerce
# งานอื่นๆ -> Other jobs
# งานโฆษณา งานสื่อ -> Media work
# งานในร้านอาหารและเครื่องดื่ม -> Jobs in restaurants and beverages
# งานในห้างสรรพสินค้า -> Work in the mall
# งานไอที -> IT jobs
# จัดซื้อ -> Purchase
# จัดซื้อ/ธุรการ/ประสานงานทั่วไป -> Purchase / Administration / General Coordination
# ช่าง -> technician
# ช่าง/ช่างเทคนิค/อิเลคโทรนิค -> Mechanic / Technician / Electronic
# ช่างเทคนิค/อิเลคโทรนิค/ซ่อมบำรุง/ช่างพิมพ์ -> Technician / Electronic / Maintenance / Printing
# ทรัพยากรบุคคล -> HR
# ท่องเที่ยว/โรงเเรม -> Travel / Hotel
# ธนาคาร /การเงิน -> Bank / Finance
# ธนาคาร การเงิน และธุรกิจ -> Bank, finance and business
# ธรณีวิทยาและป่าไม้ -> Geology and forest
# ธุรการ -> Administration
# ธุรการ/การจัดการทั่วไป -> Administration / General management
# ธุรกิจการบิน -> Aviation business
# นักวิเคราะห์/เศรษฐศาสตร์ -> Analyst / Economics
# นักเขียน/บรรณาธิการ/นักแปลภาษา -> Writer / Editor / Translator
# บริการความงาม -> Beauty service
# บริการลูกค้า -> Customer service
# บริการลูกค้า/ลูกค้าสัมพันธ์/Call Center -> Customer Service / Customer Relations / Call Center
# บริหาร -> Manage
# บริหาร/ผู้จัดการ -> Management / Manager
# บริหารอสังหาริมทรัพย์ -> Real Estate Management
# บัญชี -> account
# บันเทิง/นักแสดง/นักร้อง -> Entertainment / actor / singer
# บุคคล/ฝึกอบรม -> Person / Training
# ประกันภัย -> insurance
# ผลิต/ควบคุมคุณภาพ/โรงงาน -> Produce / Quality Control / Factory
# ผู้จัดการ/ผู้อำนวยการ/MD/CEO -> Manager / Director / MD / CEO
# พนักงานต้อนรับ -> Receptionist
# พัฒนาธุรกิจและพัฒนาองค์กร -> Business development and organization development
# ภูมิศาสตร์/แผนที่/GIS/ผังเมือง -> Geography / Map / GIS / City Plan
# มนุษยศาสตร์/ล่าม -> Humanities / Interpreter
# มัคคุเทศก์/จองห้อง/จองตั๋ว -> Guide / Booking / Ticket
# ราชการ/บริการสาธารณะ -> Government / Public Service
# ล่าม/มัคคุเทศก์/จองห้อง/จองตั๋ว -> Interpreter / Guide / Booking Room / Booking
# วิจัย/วิเคราะห์ (เศรษฐศาสตร์/หุ้น/ประกันภัย/ธนาคาร) -> Research / analysis (Economics / Stock / Insurance / Bank)
# วิทยาศาสตร์ /Lab/วิจัยและพัฒนา -> Science / Lab / Research and Development
# วิทยาศาสตร์ และวิจัยพัฒนา -> Science and research development
# วิทยาศาสตร์/Lab/วิจัยพัฒนา -> Science / Lab / Development Development
# วิศวกร -> engineer
# วิศวกรรม -> engineering
# ศิลปะ/กราฟฟิค/ออกแบบ/ช่างภาพ -> Art / Graphic / Design / Photographer
# สถาปนิก / มัณฑนากร -> Architect / Decorator
# สุขภาพ /โภชนาการ/ความงาม -> Health / Nutrition / Beauty
# ส่งเอกสาร/ขับรถ/ส่งผลิตภัณฑ์ -> Send documents / drivers / deliver products
# ห้างสรรพสินค้า -> Department store
# อสังหาริมทรัพย์ -> Real estate
# ออกแบบ/เขียนแบบ/กราฟฟิค/ช่างภาพ -> Design / Pattern / Graphic / Photographer
# ออกแบบเว็บไซต์/Web -> Website Design / Web
# ออกแบบและผลิตสื่อ -> Design and production of media
# อัญมณีและเครื่องประดับ -> Gems and jewelry
# อาหาร/เครื่องดื่ม/กุ๊ก/บาร์เทนเดอร์/พนักงานเสิร์ฟ -> Food / Beverage / Cook / Bartender / Waitress
# อื่นๆ -> Other
# เขียนแบบ/งานDrawing/AutoCad/ออกแบบวิศวกรรม -> Drawing / Drawing / AutoCAD / Engineering design
# เจ้าหน้าที่ความปลอดภัย(จป.)/สิ่งแวดล้อม -> Safety Officer / Environment
# เจ้าหน้าที่ความปลอดภัย(จป.)/สิ่งแวดล้อม/ISO -> Safety Officer / Environment / ISO
# เจ้าหน้าที่เร่งรัดหนี้สิน -> Debt staff
# เลขานุการ -> secretary
# เสื้อผ้า/สิ่งทอ/ช่างแพทเทิร์น -> Clothing / Textiles / Patterns
# แพทย์/เภสัชกร/สาธารณสุข -> Doctors / Pharmacists / Public Health
# แม่บ้าน/พี่เลี้ยง/คนสวน -> Maid / mentor / garden
# แม่บ้าน/พี่เลี้ยง/คนสวน/รปภ. -> Maid / mentor / garden / security guard
# โฆษณา /สื่อ -> Advertising / Media
# โทรคมนาคม -> telecommunications
# โยธา/สำรวจ/สถาปัตย์/มัณฑนากร/ประเมินราคา -> Civil / Survey / Architecture / Decorative / Appraiser
# โรงงาน -> factory
# โรงงาน และการผลิต -> Factory and production
# ไอที -> IT
# ไอทีและดิจิทัล -> IT and digital
# {'E-commerce': 'E-commerce ', 'Freelance': 'Freelance ', 'Part-time/พนักงานสัญญาจ้าง': 'Part-time employment contract ', 'กฎหมาย': 'law ', 'การตลาด': 'Marketing ', 'การตลาด / PR': 'Marketing / PR ', 'การผลิต / QA&QC': 'Production / QA & QC ', 'การศึกษา/ วิชาการ': 'Education / Academic ', 'การแพทย์': 'Medical ', 'ก่อสร้าง': 'Construction ', 'ขนส่ง/คลังสินค้า': 'Transport / Warehouse ', 'ขนส่งและคลังสินค้า': 'Transport and warehouse ', 'ขับรถ': 'Drive ', 'ขาย': 'sell ', 'คนขับรถ': 'Drivers ', 'คลังสินค้า': 'warehouse ', 'ความสะอาดและสวน': 'Cleanliness and garden ', 'คอมพิวเตอร์/IT/โปรแกรมเมอร์': 'Computer / IT / Programmer ', 'งาน Part-time/พนักงานชั่วคราว': 'Part-time work / temporary employees ', 'งานการตลาด งาน PR': 'Marketing Jobs PR ', 'งานการผลิต': 'Production work ', 'งานการเงิน-ธนาคาร': 'Finance - Bank ', 'งานขนส่ง': 'Transportation ', 'งานขนส่ง-คลังสินค้า': 'Transportation - Warehouse ', 'งานขาย งานบริการลูกค้า งานพัฒนาธุรกิจ': 'Customer service sales Business development ', 'งานจัดซื้อ': 'Purchasing ', 'งานธนาคาร งานการเงิน': 'Banking Banking ', 'งานธุรการ งานทรัพยากรบุคคล': 'Human Resources Administration ', 'งานนำเข้า-ส่งออก': 'Import-export ', 'งานบริการด้านการแพทย์': 'Medical Services ', 'งานบริการลูกค้า-Call Center': 'Customer Service-Call Center ', 'งานบริการเฉพาะทาง': 'Specialized services ', 'งานบริหาร': 'Management ', 'งานบัญชี': 'Accounting ', 'งานวิทยาศาสตร์ งาน Lab งานวิจัยและพัฒนา': 'Science, Lab, Research and Development ', 'งานวิศวกรรม': 'Engineering ', 'งานสุขภาพ งานโภชนาการ งานความงาม': 'Health jobs, nutrition, beauty ', 'งานอสังหาริมทรัพย์': 'Real estate ', 'งานออกแบบ': 'Design ', 'งานอีคอมเมิร์ซ': 'Ecommerce ', 'งานอื่นๆ': 'Other jobs ', 'งานโฆษณา งานสื่อ': 'Media work ', 'งานในร้านอาหารและเครื่องดื่ม': 'Jobs in restaurants and beverages ', 'งานในห้างสรรพสินค้า': 'Work in the mall ', 'งานไอที': 'IT jobs ', 'จัดซื้อ': 'Purchase ', 'จัดซื้อ/ธุรการ/ประสานงานทั่วไป': 'Purchase / Administration / General Coordination ', 'ช่าง': 'technician ', 'ช่าง/ช่างเทคนิค/อิเลคโทรนิค': 'Mechanic / Technician / Electronic ', 'ช่างเทคนิค/อิเลคโทรนิค/ซ่อมบำรุง/ช่างพิมพ์': 'Technician / Electronic / Maintenance / Printing ', 'ทรัพยากรบุคคล': 'HR ', 'ท่องเที่ยว/โรงเเรม': 'Travel / Hotel ', 'ธนาคาร /การเงิน': 'Bank / Finance ', 'ธนาคาร การเงิน และธุรกิจ': 'Bank, finance and business ', 'ธรณีวิทยาและป่าไม้': 'Geology and forest ', 'ธุรการ': 'Administration ', 'ธุรการ/การจัดการทั่วไป': 'Administration / General management ', 'ธุรกิจการบิน': 'Aviation business ', 'นักวิเคราะห์/เศรษฐศาสตร์': 'Analyst / Economics ', 'นักเขียน/บรรณาธิการ/นักแปลภาษา': 'Writer / Editor / Translator ', 'บริการความงาม': 'Beauty service ', 'บริการลูกค้า': 'Customer service ', 'บริการลูกค้า/ลูกค้าสัมพันธ์/Call Center': 'Customer Service / Customer Relations / Call Center ', 'บริหาร': 'Manage ', 'บริหาร/ผู้จัดการ': 'Management / Manager ', 'บริหารอสังหาริมทรัพย์': 'Real Estate Management ', 'บัญชี': 'account ', 'บันเทิง/นักแสดง/นักร้อง': 'Entertainment / actor / singer ', 'บุคคล/ฝึกอบรม': 'Person / Training ', 'ประกันภัย': 'insurance ', 'ผลิต/ควบคุมคุณภาพ/โรงงาน': 'Produce / Quality Control / Factory ', 'ผู้จัดการ/ผู้อำนวยการ/MD/CEO': 'Manager / Director / MD / CEO ', 'พนักงานต้อนรับ': 'Receptionist ', 'พัฒนาธุรกิจและพัฒนาองค์กร': 'Business development and organization development ', 'ภูมิศาสตร์/แผนที่/GIS/ผังเมือง': 'Geography / Map / GIS / City Plan ', 'มนุษยศาสตร์/ล่าม': 'Humanities / Interpreter ', 'มัคคุเทศก์/จองห้อง/จองตั๋ว': 'Guide / Booking / Ticket ', 'ราชการ/บริการสาธารณะ': 'Government / Public Service ', 'ล่าม/มัคคุเทศก์/จองห้อง/จองตั๋ว': 'Interpreter / Guide / Booking Room / Booking ', 'วิจัย/วิเคราะห์ (เศรษฐศาสตร์/หุ้น/ประกันภัย/ธนาคาร)': 'Research / analysis (Economics / Stock / Insurance / Bank) ', 'วิทยาศาสตร์ /Lab/วิจัยและพัฒนา': 'Science / Lab / Research and Development ', 'วิทยาศาสตร์ และวิจัยพัฒนา': 'Science and research development ', 'วิทยาศาสตร์/Lab/วิจัยพัฒนา': 'Science / Lab / Development Development ', 'วิศวกร': 'engineer ', 'ว ...
# E-commerce -> E-commerce
# Freelance -> Freelance
# Part-time/พนักงานสัญญาจ้าง -> Part-time employment contract
# กฎหมาย -> law
# การตลาด -> Marketing
# การตลาด / PR -> Marketing / PR
# การผลิต / QA&QC -> Production / QA & QC
# การศึกษา/ วิชาการ -> Education / Academic
# การแพทย์ -> Medical
# ก่อสร้าง -> Construction
# ก่อสร้าง โยธา และสถาปัตยกรรม -> Civil and architecture construction
# ขนส่ง/คลังสินค้า -> Transport / Warehouse
# ขนส่งและคลังสินค้า -> Transport and warehouse
# ขับรถ -> Drive
# ขาย -> sell
# คนขับรถ -> Drivers
# คลังสินค้า -> warehouse
# คอมพิวเตอร์/IT/โปรแกรมเมอร์ -> Computer / IT / Programmer
# งาน Part-time/พนักงานชั่วคราว -> Part-time work / temporary employees
# งานการตลาด งาน PR -> Marketing Jobs PR
# งานการผลิต -> Production work
# งานการเงิน-ธนาคาร -> Finance - Bank
# งานขนส่ง -> Transportation
# งานขนส่ง-คลังสินค้า -> Transportation - Warehouse
# งานขาย งานบริการลูกค้า งานพัฒนาธุรกิจ -> Customer service sales Business development
# งานจัดซื้อ -> Purchasing
# งานธนาคาร งานการเงิน -> Banking Banking
# งานธุรการ งานทรัพยากรบุคคล -> Human Resources Administration
# งานนำเข้า-ส่งออก -> Import-export
# งานบริการด้านการแพทย์ -> Medical Services
# งานบริการลูกค้า-Call Center -> Customer Service-Call Center
# งานบริการเฉพาะทาง -> Specialized services
# งานบริหาร -> Management
# งานบัญชี -> Accounting
# งานวิทยาศาสตร์ งาน Lab งานวิจัยและพัฒนา -> Science, Lab, Research and Development
# งานวิศวกรรม -> Engineering
# งานอสังหาริมทรัพย์ -> Real estate
# งานออกแบบ -> Design
# งานอีคอมเมิร์ซ -> Ecommerce
# งานอื่นๆ -> Other jobs
# งานโฆษณา งานสื่อ -> Media work
# งานในร้านอาหารและเครื่องดื่ม -> Jobs in restaurants and beverages
# งานในห้างสรรพสินค้า -> Work in the mall
# งานไอที -> IT jobs
# จัดซื้อ -> Purchase
# จัดซื้อ/ธุรการ/ประสานงานทั่วไป -> Purchase / Administration / General Coordination
# ช่าง -> technician
# ช่าง/ช่างเทคนิค/อิเลคโทรนิค -> Mechanic / Technician / Electronic
# ช่างเทคนิค/อิเลคโทรนิค/ซ่อมบำรุง/ช่างพิมพ์ -> Technician / Electronic / Maintenance / Printing
# ทรัพยากรบุคคล -> HR
# ท่องเที่ยว/โรงเเรม -> Travel / Hotel
# ธนาคาร /การเงิน -> Bank / Finance
# ธนาคาร การเงิน และธุรกิจ -> Bank, finance and business
# ธรณีวิทยาและป่าไม้ -> Geology and forest
# ธุรการ -> Administration
# ธุรการ/การจัดการทั่วไป -> Administration / General management
# ธุรกิจการบิน -> Aviation business
# นักวิเคราะห์/เศรษฐศาสตร์ -> Analyst / Economics
# นักเขียน/บรรณาธิการ/นักแปลภาษา -> Writer / Editor / Translator
# บริการความงาม -> Beauty service
# บริการลูกค้า -> Customer service
# บริการลูกค้า/ลูกค้าสัมพันธ์/Call Center -> Customer Service / Customer Relations / Call Center
# บริหาร/ผู้จัดการ -> Management / Manager
# บริหารอสังหาริมทรัพย์ -> Real Estate Management
# บัญชี -> account
# บันเทิง/นักแสดง/นักร้อง -> Entertainment / actor / singer
# บุคคล/ฝึกอบรม -> Person / Training
# ประกันภัย -> insurance
# ผลิต/ควบคุมคุณภาพ/โรงงาน -> Produce / Quality Control / Factory
# ผู้จัดการ/ผู้อำนวยการ/MD/CEO -> Manager / Director / MD / CEO
# พนักงานต้อนรับ -> Receptionist
# พัฒนาธุรกิจและพัฒนาองค์กร -> Business development and organization development
# ภูมิศาสตร์/แผนที่/GIS/ผังเมือง -> Geography / Map / GIS / City Plan
# มนุษยศาสตร์/ล่าม -> Humanities / Interpreter
# มัคคุเทศก์/จองห้อง/จองตั๋ว -> Guide / Booking / Ticket
# ราชการ/บริการสาธารณะ -> Government / Public Service
# ล่าม/มัคคุเทศก์/จองห้อง/จองตั๋ว -> Interpreter / Guide / Booking Room / Booking
# วิจัย/วิเคราะห์ (เศรษฐศาสตร์/หุ้น/ประกันภัย/ธนาคาร) -> Research / analysis (Economics / Stock / Insurance / Bank)
# วิทยาศาสตร์ /Lab/วิจัยและพัฒนา -> Science / Lab / Research and Development
# วิทยาศาสตร์ และวิจัยพัฒนา -> Science and research development
# วิทยาศาสตร์/Lab/วิจัยพัฒนา -> Science / Lab / Development Development
# วิศวกร -> engineer
# วิศวกรรม -> engineering
# ศิลปะ/กราฟฟิค/ออกแบบ/ช่างภาพ -> Art / Graphic / Design / Photographer
# สถาปนิก / มัณฑนากร -> Architect / Decorator
# สุขภาพ /โภชนาการ/ความงาม -> Health / Nutrition / Beauty
# ส่งเอกสาร/ขับรถ/ส่งผลิตภัณฑ์ -> Send documents / drivers / deliver products
# ห้างสรรพสินค้า -> Department store
# อสังหาริมทรัพย์ -> Real estate
# ออกแบบ/เขียนแบบ/กราฟฟิค/ช่างภาพ -> Design / Pattern / Graphic / Photographer
# ออกแบบเว็บไซต์/Web -> Website Design / Web
# ออกแบบและผลิตสื่อ -> Design and production of media
# อัญมณีและเครื่องประดับ -> Gems and jewelry
# อาหาร/เครื่องดื่ม/กุ๊ก/บาร์เทนเดอร์/พนักงานเสิร์ฟ -> Food / Beverage / Cook / Bartender / Waitress
# อื่นๆ -> Other
# เขียนแบบ/งานDrawing/AutoCad/ออกแบบวิศวกรรม -> Drawing / Drawing / AutoCAD / Engineering design
# เจ้าหน้าที่ความปลอดภัย(จป.)/สิ่งแวดล้อม -> Safety Officer / Environment
# เจ้าหน้าที่ความปลอดภัย(จป.)/สิ่งแวดล้อม/ISO -> Safety Officer / Environment / ISO
# เจ้าหน้าที่เร่งรัดหนี้สิน -> Debt staff
# เลขานุการ -> secretary
# เสื้อผ้า/สิ่งทอ/ช่างแพทเทิร์น -> Clothing / Textiles / Patterns
# แพทย์/เภสัชกร/สาธารณสุข -> Doctors / Pharmacists / Public Health
# แม่บ้าน/พี่เลี้ยง/คนสวน -> Maid / mentor / garden
# แม่บ้าน/พี่เลี้ยง/คนสวน/รปภ. -> Maid / mentor / garden / security guard
# โฆษณา /สื่อ -> Advertising / Media
# โทรคมนาคม -> telecommunications
# โยธา/สำรวจ/สถาปัตย์/มัณฑนากร/ประเมินราคา -> Civil / Survey / Architecture / Decorative / Appraiser
# โรงงาน และการผลิต -> Factory and production
# ไอที -> IT
# ไอทีและดิจิทัล -> IT and digital
# {'E-commerce': 'E-commerce ', 'Freelance': 'Freelance ', 'Part-time/พนักงานสัญญาจ้าง': 'Part-time employment contract ', 'กฎหมาย': 'law ', 'การตลาด': 'Marketing ', 'การตลาด / PR': 'Marketing / PR ', 'การผลิต / QA&QC': 'Production / QA & QC ', 'การศึกษา/ วิชาการ': 'Education / Academic ', 'การแพทย์': 'Medical ', 'ก่อสร้าง': 'Construction ', 'ก่อสร้าง โยธา และสถาปัตยกรรม': 'Civil and architecture construction ', 'ขนส่ง/คลังสินค้า': 'Transport / Warehouse ', 'ขนส่งและคลังสินค้า': 'Transport and warehouse ', 'ขับรถ': 'Drive ', 'ขาย': 'sell ', 'คนขับรถ': 'Drivers ', 'คลังสินค้า': 'warehouse ', 'คอมพิวเตอร์/IT/โปรแกรมเมอร์': 'Computer / IT / Programmer ', 'งาน Part-time/พนักงานชั่วคราว': 'Part-time work / temporary employees ', 'งานการตลาด งาน PR': 'Marketing Jobs PR ', 'งานการผลิต': 'Production work ', 'งานการเงิน-ธนาคาร': 'Finance - Bank ', 'งานขนส่ง': 'Transportation ', 'งานขนส่ง-คลังสินค้า': 'Transportation - Warehouse ', 'งานขาย งานบริการลูกค้า งานพัฒนาธุรกิจ': 'Customer service sales Business development ', 'งานจัดซื้อ': 'Purchasing ', 'งานธนาคาร งานการเงิน': 'Banking Banking ', 'งานธุรการ งานทรัพยากรบุคคล': 'Human Resources Administration ', 'งานนำเข้า-ส่งออก': 'Import-export ', 'งานบริการด้านการแพทย์': 'Medical Services ', 'งานบริการลูกค้า-Call Center': 'Customer Service-Call Center ', 'งานบริการเฉพาะทาง': 'Specialized services ', 'งานบริหาร': 'Management ', 'งานบัญชี': 'Accounting ', 'งานวิทยาศาสตร์ งาน Lab งานวิจัยและพัฒนา': 'Science, Lab, Research and Development ', 'งานวิศวกรรม': 'Engineering ', 'งานอสังหาริมทรัพย์': 'Real estate ', 'งานออกแบบ': 'Design ', 'งานอีคอมเมิร์ซ': 'Ecommerce ', 'งานอื่นๆ': 'Other jobs ', 'งานโฆษณา งานสื่อ': 'Media work ', 'งานในร้านอาหารและเครื่องดื่ม': 'Jobs in restaurants and beverages ', 'งานในห้างสรรพสินค้า': 'Work in the mall ', 'งานไอที': 'IT jobs ', 'จัดซื้อ': 'Purchase ', 'จัดซื้อ/ธุรการ/ประสานงานทั่วไป': 'Purchase / Administration / General Coordination ', 'ช่าง': 'technician ', 'ช่าง/ช่างเทคนิค/อิเลคโทรนิค': 'Mechanic / Technician / Electronic ', 'ช่างเทคนิค/อิเลคโทรนิค/ซ่อมบำรุง/ช่างพิมพ์': 'Technician / Electronic / Maintenance / Printing ', 'ทรัพยากรบุคคล': 'HR ', 'ท่องเที่ยว/โรงเเรม': 'Travel / Hotel ', 'ธนาคาร /การเงิน': 'Bank / Finance ', 'ธนาคาร การเงิน และธุรกิจ': 'Bank, finance and business ', 'ธรณีวิทยาและป่าไม้': 'Geology and forest ', 'ธุรการ': 'Administration ', 'ธุรการ/การจัดการทั่วไป': 'Administration / General management ', 'ธุรกิจการบิน': 'Aviation business ', 'นักวิเคราะห์/เศรษฐศาสตร์': 'Analyst / Economics ', 'นักเขียน/บรรณาธิการ/นักแปลภาษา': 'Writer / Editor / Translator ', 'บริการความงาม': 'Beauty service ', 'บริการลูกค้า': 'Customer service ', 'บริการลูกค้า/ลูกค้าสัมพันธ์/Call Center': 'Customer Service / Customer Relations / Call Center ', 'บริหาร/ผู้จัดการ': 'Management / Manager ', 'บริหารอสังหาริมทรัพย์': 'Real Estate Management ', 'บัญชี': 'account ', 'บันเทิง/นักแสดง/นักร้อง': 'Entertainment / actor / singer ', 'บุคคล/ฝึกอบรม': 'Person / Training ', 'ประกันภัย': 'insurance ', 'ผลิต/ควบคุมคุณภาพ/โรงงาน': 'Produce / Quality Control / Factory ', 'ผู้จัดการ/ผู้อำนวยการ/MD/CEO': 'Manager / Director / MD / CEO ', 'พนักงานต้อนรับ': 'Receptionist ', 'พัฒนาธุรกิจและพัฒนาองค์กร': 'Business development and organization development ', 'ภูมิศาสตร์/แผนที่/GIS/ผังเมือง': 'Geography / Map / GIS / City Plan ', 'มนุษยศาสตร์/ล่าม': 'Humanities / Interpreter ', 'มัคคุเทศก์/จองห้อง/จองตั๋ว': 'Guide / Booking / Ticket ', 'ราชการ/บริการสาธารณะ': 'Government / Public Service ', 'ล่าม/มัคคุเทศก์/จองห้อง/จองตั๋ว': 'Interpreter / Guide / Booking Room / Booking ', 'วิจัย/วิเคราะห์ (เศรษฐศาสตร์/หุ้น/ประกันภัย/ธนาคาร)': 'Research / analysis (Economics / Stock / Insurance / Bank) ', 'วิทยาศาสตร์ /Lab/วิจัยและพัฒนา': 'Science / Lab / Research and Development ', 'วิทยาศาสตร์ และวิจัยพัฒนา': 'Science and research development ', 'วิทยาศาสตร์/Lab/วิจัยพัฒนา': 'Science / Lab / Development Development ', 'วิศวกร': 'engineer ', 'วิศวกรรม': 'engineering ', 'ศิลปะ/กราฟฟิค/ออกแบบ/ช่างภาพ': 'Art / G ...
#    job_id                                          job_title  \
# 0   25320                          พนักงานขับรถรับส่งพนักงาน
# 1   25321                       ผู้ประเมินราคางานตกแต่งภายใน
# 2   25322                   นักออกแบบกราฟิก (Graphic design)
# 3   25323  พนักงานขับรถส่งสินค้า ประจำศูนย์กระจายสินค้า ส...
# 4   25324                 พนักงานขายทางโทรศัพท์​ / Telesales
#
#                                            role_name  \
# 0                                           Drivers
# 1  Civil / Survey / Architecture / Decorative / A...
# 2             Art / Graphic / Design / Photographer
# 3                                           Drivers
# 4                                              sell
#
#                      sub_role_name  \
# 0                    คนขับรถ อื่นๆ
# 1                      ประเมินราคา
# 2         Graphic Design/สิ่งพิมพ์
# 3                 คนขับรถส่งสินค้า
# 4  พนักงานขายทางโทรศัพท์/Telesales
#
#                                             location   latitude  longitude  \
# 0  กรุงเทพมหานคร(เขตพระโขนง),กรุงเทพมหานคร(เขตสวน...        NaN        NaN
# 1                           อ.เมืองนนทบุรี จ.นนทบุรี  13.872826  100.53001
# 2                           เขตคลองสาน กรุงเทพมหานคร        NaN        NaN
# 3                         กรุงเทพมหานคร(เขตคันนายาว)        NaN        NaN
# 4                           เขตปทุมวัน กรุงเทพมหานคร        NaN        NaN
#
#                                 salary company_name
# 0                              ตามตกลง       83akmq
# 1  25,000-35,000 ขึ้นอยู่กับประสบการณ์       b57auw
# 2                    18,000-25,000 บาท       362uhk
# 3                        16,000-18,000       yp1i9y
# 4                  15,000 + คอมมิสชั่น       4s96ty
#    job_id                                          job_title  \
# 0       0                     Warehouse & Distribution Sales
# 1       1  เจ้าหน้าที่บรรณาธิการหนังสือเรียน กลุ่มสาระสัง...
# 2       2   Education Consultant ประจำสาขา เซ็นทรัลแจ้งวัฒนะ
# 3       3  ★★เริ่มงาน 25 ม.ค.นี้  (ฝ่ายขายประจำOffice รับ...
# 4       4          ผู้จัดการอาคาร (ใกล้ ม.ธรรมศาสตร์ รังสิต)
#
#                                            role_name  \
# 0                                              sell
# 1                      Writer / Editor / Translator
# 2                                              sell
# 3  Customer Service / Customer Relations / Call C...
# 4                     Manager / Director / MD / CEO
#
#                              sub_role_name                   location  \
# 0                      พนักงานขาย/Sales/AE         อ.ศรีราชา จ.ชลบุรี
# 1                               บรรณาธิการ  กรุงเทพมหานคร(เขตบางซื่อ)
# 2                                 ขายอื่นๆ          นนทบุรี(ปากเกร็ด)
# 3  บริการ/ลูกค้าสัมพันธ์/Call Center อื่นๆ      กรุงเทพมหานคร(ทุกเขต)
# 4                          ผู้จัดการทั่วไป      อ.คลองหลวง จ.ปทุมธานี
#
#     latitude   longitude           salary company_name
# 0        NaN         NaN          ไม่ระบุ       vueoeo
# 1        NaN         NaN          ตามตกลง       30jfum
# 2        NaN         NaN    15,000-16,000       1d36pp
# 3        NaN         NaN    13,000-50,000       wqalnh
# 4  14.064528  100.609091  28,000 - 33,000       p1he99

# %%
active_sub_translations = translation(active['sub_role_name'])
previous_sub_translations = translation(previous['sub_role_name'])

active['sub_role_name'].replace(active_sub_translations, inplace=True)
previous['sub_role_name'].replace(previous_sub_translations, inplace=True)
# Out:
# Advertising/Creative -> Advertising/Creative
# Application   Support/ Helpdesk -> Application   Support/ Helpdesk
# Application Network -> Application Network
# BOI -> Book
# Back End Developer -> Back End Developer
# Bancassurance -> Bancassurance
# Brand Marketing -> Brand Marketing
# Brand/Product Marketing -> Brand/Product Marketing
# Business Analyst (BA) -> Business Analyst (ba)
# Business Analyst(BA) -> Business Analyst (ba)
# Call Center -> Call Center
# Computer Graphic/3D/Animation -> Computer Graphic/3D/Animation
# Copy writer -> Copy writer
# Credit Control -> Credit Control
# Data Engineer/Big Data -> Data Engineer/Big Data
# Data Scientist -> Data Scientist
# Database Administration -> Database Administration
# DevOps Engineer -> DevOps Engineer
# Digital Marketing -> Digital Marketing
# E-commerce อื่นๆ -> Other e-commerce
# Full Stack Developer -> Full Stack Developer
# Graphic Design/สิ่งพิมพ์ -> GRAPHIC DESIGN / Paper
# Hardware -> Hardware
# IT Audit -> IT Audit
# IT Manager -> IT Manager
# IT Manager/Senior Programmer -> IT Manager/Senior Programmer
# IT Project Manager -> IT Project Manager
# IT Security -> IT Security
# IT Support / Technical Support -> IT Support / Technical Support
# IT Support Help Desk -> IT Support Help Desk
# IT/Admin/Network Admin -> IT/Admin/Network Admin
# MD/CEO -> MD/CEO
# MIS -> What
# Merchandiser -> Merchandiser
# Mobile Application -> Mobile Application
# Network -> Network
# Operation -> Operation
# PR Marketing/Marketing Communications -> Marketing / Marketing Communications
# Part-time/พนักงานสัญญาจ้าง อื่นๆ -> Part-time / other employees
# Pretty/MC -> Pretty/MC
# Programmer -> Programmer
# Programmer/Developer -> Programmer/Developer
# Project Manager(PM) -> Project Manager(PM)
# Retail Banking -> Retail Banking
# SEO -> THIS
# Shipping -> Shipping
# Software Engineer -> Software Engineer
# Software Tester -> Software tester
# Supply Chain -> Supply Chain
# System Admin -> System Admin
# System Analyst -> System Analyst
# System Analyst(SA) -> System Analyst(SA)
# System Engineer and Architect -> System Engineer and Architect
# Sytem Engineer -> System Engineer
# Technical Support/Help Desk -> Technical Support/Help Desk
# Tester -> Tester
# Trading -> Trading
# Treasury -> Treasury
# UX/UI -> UX / UI
# Underwriter -> Underwriter
# Web Content -> Web Content
# Web Content/Web Master -> Web Content/Web Master
# Web Design -> Web Design
# Web Programmer -> Web programs
# Web Programmer/Web Master -> Web Programs / Web Master
# กฎหมาย อื่นๆ -> Other laws
# กราฟฟิค/สื่อสิงพิมพ์/Designer -> Graphic / Media Singing / Designer
# กราฟิกดีไซน์ -> Graphic design
# การค้าระหว่างประเทศ -> International trade
# การตลาด -> Marketing
# การตลาดดิจิทัล -> Digital marketing
# การตลาดทั่วไป -> General marketing
# การตลาดอื่นๆ -> Other marketing
# การบิน -> Aviation
# การศึกษา/วิชาการอื่นๆ -> Education / Other academic
# การส่งเสริมการลงทุน(BOI) -> Investment Promotion (BOI)
# การเกษตร/ป่าไม้/ประมง -> Agriculture / Forestry / Fishing
# การเงิน -> finance
# การแพทย์อื่นๆ -> Other medical
# กิจกรรมการตลาด -> Marketing activities
# กุ๊กอาหารไทย/นานาชาติ -> Thai / International Food Cook
# ก่อสร้าง ควบคุมอาคาร -> Building control construction
# ก่อสร้างอื่นๆ -> Other construction
# ขนส่ง/คลังสินค้า อื่นๆ -> Transport / Other warehouses
# ขนส่งสินค้า -> Cargo
# ขับรถทั่วไป -> General driving
# ขับรถส่งเอกสาร ส่งผลิตภัณฑ์ -> Driving, sending documents, sending products
# ขับรถส่งเอกสาร/ส่งผลิตภัณฑ์ -> Drive documents / send products
# ขาย -> sell
# ขายตรง -> Direct sale
# ขายทางโทรศัพท์ -> Sell by phone
# ขายปลีก -> retail
# ขายส่ง -> wholesale
# ขายอื่นๆ -> Other sales
# คนขับรถ อื่นๆ -> Other drivers
# คนขับรถบรรทุก -> Truck driver
# คนขับรถผู้บริหาร -> Executive driver
# คนขับรถรับ-ส่งเอกสาร -> Driver - Document delivery
# คนขับรถส่งสินค้า -> Driver
# คนสวน -> Gardener
# ครีเอทีฟ -> Creative
# ครู -> teacher
# คลังสินค้า -> warehouse
# ควบคุมคุณภาพ -> Quality control
# ควบคุมคุณภาพ/QC/QA/QM -> Quality control / QC / QA / QM
# ควบคุมดูแลเครื่องจักร -> Supervise the machine
# ความงาม -> Beauty
# คีย์ข้อมูล -> Data key
# งาน Copy Writer -> Copy writer
# งาน IT Project -> IT Project
# งาน IT Security -> IT Security
# งาน IT Support -> Support
# งาน Lab -> Lab
# งาน MIS -> MIS
# งาน Software -> Software
# งาน Supply Chain -> Supply Chain
# งานกฎหมาย -> Legal work
# งานการตลาดทั่วไป -> General marketing work
# งานการตลาดอื่นๆ -> Other marketing work
# งานการเงิน -> Finance work
# งานขนส่ง -> Transportation
# งานขายตรง -> Direct sales
# งานขายส่ง -> Wholesale job
# งานขายอื่นๆ -> Other sales work
# งานคลังสินค้า -> Warehouse
# งานจัดซื้อ งานจัดหา -> Procurement
# งานดูแลระบบ Network -> Network Administration
# งานตรวจสอบคุณภาพ -> Quality inspection
# งานตรวจสอบบัญชี -> Audit
# งานต้อนรับลูกค้า -> Customer welcoming
# งานที่ปรึกษาไอที -> IT Advisor
# งานธุรการ งานการจัดการทั่วไป -> Administration, general management
# งานธุรการบัญชี -> Account administration
# งานนำเข้า-ส่งออก -> Import-export
# งานบรรณาธิการ งานข่าว -> News Editorial News
# งานบริการด้านการเงิน -> Financial services
# งานบริการลูกค้า -> Customer service
# งานบริหารกองทุน -> Fund management
# งานบริหารการขาย -> Sales Management
# งานบริหารทั่วไป -> General management
# งานบริหารอสังหาริมทรัพย์ -> Real Estate Management
# งานบริหารแบรนด์สินค้า งานบริหารตราสินค้า -> Brand Management Brand management
# งานบัญชี -> Accounting
# งานบัญชีทั่วไป -> General Accounting
# งานบัญชีภาษีอากร -> Taxation
# งานบัญชีรับ-จ่าย -> Accounting
# งานบัญชีลูกหนี้-เจ้าหนี้ -> Accounts Receivables - Creditors
# งานบัญชีอื่นๆ -> Other accounting
# งานผลิตอื่นๆ -> Other production
# งานผู้บริหารระดับสูง -> Senior Management
# งานฝึกอบรม -> Training
# งานพยาบาล -> Nursing
# งานพัฒนาธุรกิจ -> Business development
# งานลงทุน -> Investment work
# งานวิศวกรการผลิต งานวิศวกรโรงงาน -> Production Engineer Factory engineer
# งานวิศวกรพลังงาน -> Energy Engineer
# งานวิศวกรรมอุตสาหการ -> Industrial Engineering
# งานวิศวกรสิ่งแวดล้อม งาน จป -> Environmental Engineer Jobs
# งานวิศวกรเครื่องกล -> Mechanical Engineer
# งานวิศวกรไฟฟ้า งานวิศวกรอิเล็กทรอนิกส์ -> Electrical engineer Electronics Engineer
# งานวิศวะอื่นๆ -> Other engineering work
# งานวิเคราะห์การลงทุน -> Investment analysis
# งานวิเคราะห์การลงทุน-กองทุน -> Investment Analysis - Fund
# งานว่าจ้างและเงินเดือน -> Hiring and salary
# งานสปาบำบัด งานฟิตเนส งานกีฬา งานสันทนาการ -> Spa Therapy Fitness Work Sports, Recreational jobs
# งานสรรหาบุคลากร -> Recruitment
# งานสินเชื่อ -> Loan
# งานสินเชื่อ-วิเคราะห์สินเชื่อ -> Loan - Credit Analysis
# งานสื่อสารการตลาด -> Marketing Communication
# งานออกแบบมัลติมีเดีย -> Multimedia design
# งานอื่นๆ -> Other jobs
# งานเภสัชกรรม -> Pharmaceutical work
# งานเร่งรัดหนี้สิน -> Debt collection work
# งานเลขานุการ งาน Personal Assistant -> Secretary of Personal Assistant
# งานแรงงานสัมพันธ์ -> Labor Relations
# งานโฆษณาอื่นๆ -> Other advertising
# งานโปรแกรมเมอร์ -> Programmer
# จองห้อง/จองตั๋ว/Tour Operations -> Booking / Booking Ticket / Tour Operations
# จัดซื้อ -> Purchase
# จัดซื้อ จัดหา -> Purchasing
# จัดซื้อ/จัดหา -> Purchasing / Procurement
# จัดซื้ออื่นๆ -> Other purchasing
# จัดซื้ออุตสาหกรรม -> Purchase industry
# จัดซื้อเครื่องใช้ในครัวเรือน -> Purchase household appliances
# จัดซื้อเสื้อผ้า -> Purchase clothes
# จัดเก็บ -> Store
# ชีววิทยา -> biology
# ช่าง Jewelry/ทอง/เงิน -> Jewelry / gold / silver
# ช่าง/คนงานทั่วไป -> Mechanic / General workers
# ช่างCNC/Mold/กลึง/เจียระไน -> CNC / MOLD / Lathe / uncut
# ช่างCNC/กลึง/เจียระไน -> CNC technician / turning / uncut
# ช่างซ่อมบำรุง -> Maintenance
# ช่างฝีมือ -> Craftsman
# ช่างพิมพ์ -> Print technician
# ช่างภาพ -> Photographer
# ช่างภาพ ตัดต่อ -> Photo montage
# ช่างภาพ/ตัดต่อ -> Photographer / Montage
# ช่างยนต์ ช่างกลโรงงาน -> Mechanic mechanic mechanic factory
# ช่างยนต์/ช่างกลโรงงาน -> Mechanic / Mechanic Factory
# ช่างศิลป์(Sculpture/Print/Paint/Drawing) -> SCULPTURE / PRINT / PAINT / DRAWING)
# ช่างเทคนิค -> Technician
# ช่างเทคนิค/อิเลคโทรนิคอื่นๆ -> Other technicians / electronic technicians
# ช่างแพทเทิร์น/มาร์ก/ตัดผ้า -> Pattern Pattern / Mark / Cutting Cloth
# ช่างไฟฟ้า/อิเลคโทรนิค/คอมพิวเตอร์/สื่อสาร -> Electrician / Electronic / Computer / Communication
# ดูแลระบบ Network -> Network administration
# ตรวจสอบคุณภาพ /QC/QA/QM/ISO -> Quality inspection / QC / QA / QM / ISO
# ตรวจสอบคุณภาพอัญมณี -> Check the gem light quality
# ตรวจสอบบัญชี -> Check account
# ตรวจสอบอาคาร/สำรวจ -> Building inspection / exploration
# ตรวจสินค้า -> Check the product
# ตัวแทนประกันภัย -> Insurance agent
# ต้อนรับลูกค้า -> Welcome customers
# ทนายความ -> lawyer
# ทันตแพทย์ -> dentist
# ทัวร์/บริษัททัวร์ -> Tour / Tour Company
# ที่ปรึกษาการขาย -> Sales consultant
# ที่ปรึกษาด้านกฎหมาย -> Legal consultant
# ที่ปรึกษาทางการเงิน -> Financial advisor
# ที่ปรึกษาอสังหาริมทรัพย์ -> Real estate consultant
# ที่ปรึกษาไอที -> IT consultant
# ท่องเที่ยวอื่นๆ -> Other travel
# ธนาคาร/การเงินอื่นๆ -> Bank / Other Finance
# ธรณีวิทยาและป่าไม้อื่นๆ -> Other geology and forests
# ธุรการ/การจัดการทั่วไป -> Administration / General management
# ธุรการทั่วไป -> General Administration
# ธุรการบัญชี -> Accounting Administration
# ธุรการฝ่ายขาย -> Sales Administration
# ธุรการอื่นๆ/การจัดการทั่วไปอื่นๆ -> Other administrative / other general management
# ธุรกิจการบิน -> Aviation business
# นักกฎหมาย -> Lawyer
# นักกายภาพบำบัด -> Physical therapist
# นักข่าว -> journalist
# นักคณิตศาสตร์/สถิติ -> Mathematician / Statistics
# นักธรณีวิทยา -> Geologist
# นักปฐพี -> Gate
# นักวิจัยและพัฒนาผลิตภัณฑ์ -> Product research and development
# นักวิทยาศาสตร์/เคมี/ชีวะ/ฟิสิกส์ -> Scientists / Chemistry / Chemical / Physics
# นักวิทยาศาสตร์การอาหาร -> Food scientists
# นักวิทยาศาสตร์ข้อมูล -> Data scientists
# นักวิเคราะห์/เศรษฐศาสตร์ อื่นๆ -> Analyst / other economics
# นักศึกษาจบใหม่ -> New graduate student
# นักศึกษาฝึกงาน -> Internship students
# นักสถิติการประกันภัย -> Insurance statistics
# นักออกแบบ UI/UX -> UI / UX designer
# นักออกแบบ UX/UI -> UX / UI designer
# นักเขียน -> Writer
# นักเขียน/บรรณาธิการ/นักแปลภาษา อื่นๆ -> Writer / Editor / Other translators
# นักแปลภาษา -> Language translator
# นักแสดง -> Actor
# นักโบราณคดี ประวัติศาสตร์ -> Archaeologist history
# นิติกร -> lawyer
# บรรณาธิการ -> editor
# บรรณารักษ์ -> librarian
# บริการ/ลูกค้าสัมพันธ์/Call Center อื่นๆ -> Services / Customer Relations / Call Center
# บริการด้านการเงิน -> Financial services
# บริการลูกค้า ลูกค้าสัมพันธ์ -> Customer service customer service
# บริการลูกค้า/ลูกค้าสัมพันธ์(CRM) -> Customer Service / Customer Service (CRM)
# บริการสังคม -> Social Services
# บริหารกองทุน -> Fund management
# บริหารการขาย -> Sales management
# บริหารการขาย/SE -> Sales / SE
# บริหารการตลาด -> Marketing Management
# บริหารการผลิต -> Production management
# บริหารการโรงแรม/รีสอร์ท/ท่องเที่ยว -> Hotel / Resort / Travel Management
# บริหารความมั่งคั่ง -> Wealth Management
# บริหารความเสี่ยง -> Risk management
# บริหารค่าจ้าง บริหารผลตอบแทน -> Manage wages Return management
# บริหารทั่วไป -> General administration
# บริหารสินทรัพย์ -> Asset Management
# บริหารอสังหาริมทรัพย์ -> Real Estate Management
# บริหารแบรนด์สินค้า ตราสินค้า ผลิตภัณฑ์ -> Brand management, brand products
# บัญชี -> account
# บัญชีภาษีอากร -> Tax account
# บัญชีรับ-จ่าย -> Account
# บัญชีลูกหนี้-เจ้าหนี้ -> Accounts receivable - creditors
# บัญชีอื่นๆ -> Other accounts
# บันเทิง/นักแสดง/นักร้อง อื่นๆ -> Entertainment / Actress / Other singers
# บาริสต้า -> Barista
# บาร์เทนเดอร์ -> Bartender
# บุคคล/ฝึกอบรมอื่นๆ -> Person / other training
# ประกันภัยอื่นๆ -> Other insurance
# ประชาสัมพันธ์ทั่วไป -> General public relations
# ประสานงานขาย -> Coordinate sales
# ประสานงานทั่วไป -> General coordination
# ประเมินราคา -> Appraise
# ปรึกษาการขาย -> Sales consultation
# ป้อนข้อมูล -> Input
# ผลิตทั่วไป -> General production
# ผลิตสื่อ -> Media production
# ผลิตอัญมณี เครื่องประดับ -> Manufacture of jewelry
# ผลิตอื่นๆ -> Other production
# ผลิตเสื้อผ้า สิ่งทอ -> Production of textiles
# ผู้จัดการทั่วไป -> General manager
# ผู้จัดการฝึกหัด -> Trainer
# ผู้จัดการฝ่าย -> Manager
# ผู้จัดการฝ่ายการเงิน/CFO -> Finance Manager / CFO
# ผู้จัดการฝ่ายขาย -> Sales manager
# ผู้จัดการร้าน -> Shop manager
# ผู้จัดการสาขา -> Branch manager
# ผู้จัดการแผนก -> Department manager
# ผู้จัดการโรงงาน -> Factory manager
# ผู้ช่วยกุ๊ก -> Assistant
# ผู้ช่วยทางการแพทย์ -> Medical assistant
# ผู้ช่วยผู้จัดการ -> Assistant
# ผู้ช่วยผู้จัดการสาขา -> Assistant Branch Manager
# ผู้ช่วยเลขานุการ -> Secretary assistant
# ผู้ดูแลระบบเครือข่าย -> Network administrator
# ผู้ดูแลระบบโทรคมนาคม -> Telecommunications administrator
# ผู้ดูแลและแก้ไขระบบโทรคมนาคม -> Telecommunications and editing systems
# ผู้บริหารระดับสูง -> High-level executives
# ผู้บริหารโครงการ -> Project Manager
# ผู้อำนวยการ/รองผู้อำนวยการ -> Director / Deputy Director
# ฝึกอบรม -> Train
# ฝ่ายผลิต/โรงงาน -> Production / Factory
# พนักงาน แผนกตรวจรับสินค้า/สต็อกรูม -> Employees, department, receiving goods / collection stock
# พนักงาน แผนกพื้นที่เช่า และศูนย์อาหาร -> Staff, department, rental area And food centers
# พนักงาน แผนกสินค้าทั่วไป -> General product department staff
# พนักงาน แผนกอาหารสด/อาหารแห้ง -> Fresh food department staff / dried food
# พนักงานPart-time -> Part-time employees
# พนักงานPart-time(รายวัน/รายชั่วโมง) -> Part-time employees (daily / hourly)
# พนักงานขับรถ/ขับรถผู้บริหาร -> Driver / Driving Executive
# พนักงานขาย -> Salesperson
# พนักงานขาย/Sales/AE -> Salesman / Sales / AE
# พนักงานขายทางโทรศัพท์ -> Telephone
# พนักงานขายทางโทรศัพท์/Telesales -> Telephone sales staff / telesales
# พนักงานชั่วคราว(Temporary) -> Temporary staff
# พนักงานดูแลลานจอดรถ -> Staff take care of the parking lot
# พนักงานต้อนรับ -> Receptionist
# พนักงานทำความสะอาด/แม่บ้าน -> Cleaning staff / housewife
# พนักงานฝ่ายบุคคล -> Individual
# พนักงานฝ่ายบุคคล(HR) -> Personnel (HR)
# พนักงานร้านกาแฟ/Barista -> Coffee shop staff / Barista
# พนักงานล้างจาน -> Dishwasher
# พนักงานสัญญาจ้าง -> Employment employee
# พนักงานเขียนแบบ/AutoCad/Draftman -> Staff / AutoCAD / Draftman
# พนักงานเสิร์ฟ -> Waiter
# พนักงานแนะนำสินค้า (PC) -> Product Introduction (PC)
# พนักงานแนะนำสินค้าประจำร้าน/PC -> Staff in the shop / PC
# พนักงานแผนกบริการลูกค้า/แคชเชียร์ -> Customer service staff / cashier
# พนักงานโรงงานเสื้อผ้า/สิ่งทอ -> Factory / Textile factory
# พยาบาล -> nurse
# พัฒนาธุรกิจ -> Business development
# พัฒนาธุรกิจและพัฒนาองค์กร อื่นๆ -> Business development and other organizational development
# พัฒนาผลิตภัณฑ์ -> Product development
# พัฒนาองค์กร -> Organization development
# พัฒนาองค์กร/ISO -> Organization Development / ISO
# พิธีกร ผู้ประกาศ / MC -> MC announcer / MC
# พิมพ์ -> print
# พิสูจน์อักษร -> Proofread
# พี่เลี้ยงเด็ก -> Babysitter
# พื้นที่/แลนด์สเคป -> Area / Landscape
# ฟิสิกส์ -> physics
# ภูมิทัศน์ -> Landscape
# ภูมิศาสตร์/แผนที่/GIS/ผังเมือง อื่นๆ -> Geography / Map / GIS / Other city plan
# ภูมิสถาปัตย์ -> Landscape architecture
# มนุษยศาสตร์/ล่าม อื่นๆ -> Humanities / Other Interpreters
# มัคคุเทศก์ -> guide
# มัคคุเทศก์/จองห้อง/จองตั๋ว อื่นๆ -> Guide / Booking Room / Booking other tickets
# มัณฑนากร -> Decorator
# รัฐศาสตร์การปกครอง -> Political Science
# ราชการ -> service
# ราชการ/บริการสาธารณะ อื่นๆ -> Government / other public services
# ราชการทหาร -> Military service
# ล่าม/นักแปล -> Interpreter / Translator
# ล่ามภาษาจีน -> Chinese interpreter
# ล่ามภาษาญี่ปุ่น -> Japanese interpreter
# วางกลยุทธ์การโฆษณา -> Place advertising strategies
# วางแผนการผลิต -> Production plan
# วางแผนการผลิต งานควบคุมการผลิต -> Production plan Production control
# วางแผนการผลิต/ควบคุมการผลิต -> Production / Production Control Planning
# วิจัยการตลาด -> Market Research
# วิจัยตลาด -> Market research
# วิจัยและพัฒนา -> Research and development
# วิทยาศาสตร์ /Lab/วิจัยและพัฒนา อื่นๆ -> Science / Lab / Other research and development
# วิทยาศาสตร์การกีฬา -> Sports science
# วิทยาศาสตร์การอาหาร -> Food science
# วิทยาศาสตร์การอาหาร (Food Science) -> Food Science
# วิทยาศาสตร์สิ่งแวดล้อม -> Environmental science
# วิทยุโทรทัศน์ -> Television
# วิศวกรการผลิต -> Production engineer
# วิศวกรการผลิต/วิศวกรโรงงาน -> Production Engineer / Factory Engineer
# วิศวกรขาย -> Sales engineer
# วิศวกรคอมพิวเตอร์ -> Computer engineer
# วิศวกรชีวการแพทย์ -> Biomedical Engineer
# วิศวกรซ่อมบำรุง -> Maintenance engineer
# วิศวกรบำรุงรักษา -> Maintenance engineer
# วิศวกรประเมินราคา -> Evaluation engineer
# วิศวกรพลังงาน -> Energy engineer
# วิศวกรพอลิเมอร์ -> Polymer engineer
# วิศวกรยานยนต์ -> Automotive Engineer
# วิศวกรรมงานระบบประกอบอาคาร -> Engineering building system
# วิศวกรรมอุตสาหการ -> Industrial engineering
# วิศวกรรมเคมี -> Chemical Engineering
# วิศวกรสำรวจ -> Explore engineer
# วิศวกรสิ่งทอ -> Textile engineer
# วิศวกรสิ่งแวดล้อม -> Environmental engineer
# วิศวกรสื่อสาร -> Communication engineer
# วิศวกรออกแบบ -> Design engineer
# วิศวกรอุตสาหการ/โรงงาน -> Industrial Engineer / Factory
# วิศวกรเขียนแบบ -> Write engineer
# วิศวกรเคมี/ปิโตรเลียม -> Chemical / Petroleum Engineer
# วิศวกรเครื่องกล -> Mechanical engineer
# วิศวกรเครื่องกล/ยานยนต์ -> Mechanical / Automotive Engineer
# วิศวกรแมคคาทรอนิกส์ -> Machatronics Engineer
# วิศวกรโครงการ -> Project Engineer
# วิศวกรโทรคมนาคม -> Telecommunications engineer
# วิศวกรโยธา -> Civil Engineer
# วิศวกรโยธา/ก่อสร้าง -> Civil / Construction Engineer
# วิศวกรไฟฟ้า/วิศวกรอิเล็กทรอนิกส์ -> Electrical Engineer / Electronics Engineer
# วิศวกรไฟฟ้า/อิเลคโทรนิค/สื่อสาร -> Electrical / Electronic Engineer / Communication
# วิศวะอื่นๆ -> Other engineering
# วิเคราะห์การลงทุน -> Investment analysis
# วิเคราะห์ข้อมูลทั่วไป -> General information analysis
# วิเคราะห์สถิติ -> Statistical analysis
# วิเคราะห์สินเชื่อ/อนุมัติสินเชื่อ -> Credit analysis / Credit approval
# ว่าจ้างและเงินเดือน -> Hiring and salary
# สถาปนิก -> architect
# สถาปนิก / มัณฑนากร อื่นๆ -> Architects / Other decorations
# สถาปัตยกรรม -> architecture
# สถาปัตยกรรมภายในและมัณฑนศิลป์ -> Interior architecture and decorative arts
# สปาบำบัด/ฟิตเนส/กีฬา/สันทนาการ -> Spa Therapy / Fitness / Sport / Recreation
# สรรหาบุคลากร -> Recruit
# สหกิจศึกษา -> Cooperative Education
# สอนพิเศษ/ติวเตอร์ -> Tutorial / Tutor
# สัตวแพทย์ -> veterinary
# สัตวแพทย์/สัตวบาล -> Veterinary / animal husbandry
# สำรวจ -> survey
# สินเชื่อ -> Loan
# สื่อสารการตลาด -> Marketing communication
# สื่อสิ่งพิมพ์ -> Publication
# สุขภาพ -> health
# สุขภาพ /โภชนาการ/ความงาม อื่นๆ -> Health / Nutrition / Other beauty
# ส่งออก/นำเข้า -> Export / Import
# หัวหน้า/ผู้จัดการ/ผู้บริหาร -> Chief / Manager / Manager
# หัวหน้า/ผู้จัดการ/ผู้บริหาร อื่นๆ -> Chief / Manager / Other Manager
# อสังหาริมทรัพย์อื่นๆ -> Other real estate
# ออกแบบ/เขียนแบบ/กราฟฟิค/ช่างภาพ อื่นๆ -> Design / Write / Graphic / Other photographers
# ออกแบบกราฟิก -> Graphic design
# ออกแบบการจัดวางสินค้า -> Product placement design
# ออกแบบตกแต่งภายใน -> Interior design
# ออกแบบผลิตภัณฑ์/ออกแบบบรรจุภัณฑ์ -> Product design / packaging design
# ออกแบบมัลติมีเดีย -> Multimedia design
# ออกแบบลายผ้า/เสื้อผ้า -> Striped fabric design / clothing
# ออกแบบสิ่งพิมพ์ -> Publication design
# ออกแบบเครื่องประดับ -> Jewelry design
# ออกแบบเว็บไซต์ - Content -> Website Design - Content
# ออกแบบแฟชั่น/ดีไซน์เนอร์ -> Fashion design / designer
# อัญมณีและเครื่องประดับอื่นๆ -> Other gems and jewelry
# อาจารย์ -> professor
# อาหาร/เครื่องดื่ม/กุ๊ก/บาร์เทนเดอร์/พนักงานเสิร์ฟอื่นๆ -> Food / Beverage / Cook / Bartender / Other waiters
# อาหารและเครื่องดื่ม -> Food and drink
# อีเว้นท์ -> Event
# อื่นๆ -> Other
# เคมี -> chemical
# เจ้าหน้าที่ความปลอดภัย -> Safety officer
# เจ้าหน้าที่ความปลอดภัย(จป.) -> Safety Officer (Chor.)
# เจ้าหน้าที่ความปลอดภัย(จป.)/สิ่งแวดล้อม อื่นๆ -> Safety Officer (Chor.) / Other Environment
# เจ้าหน้าที่ดูแลลูกค้า (Teller) -> Customer care staff (Teller)
# เจ้าหน้าที่ตรวจสอบทุจริต -> Fraud
# เจ้าหน้าที่ตรวจสอบภายใน -> Internal Audit Officer
# เจ้าหน้าที่ป้องกันการสูญเสีย -> Defense staff
# เจ้าหน้าที่ฝึกอบรม/วิทยากร -> Training staff / speaker
# เจ้าหน้าที่รักษาความปลอดภัย/รปภ. -> Security Officer / Security Center
# เจ้าหน้าที่วิเคราะห์ข้อมูล -> Data analysis officer
# เจ้าหน้าที่สินไหมทดแทน -> Claims Officer
# เจ้าหน้าที่สิ่งแวดล้อม -> Environmental staff
# เจ้าหน้าที่ห้องปฎิบัติการ (Lab) -> Laboratory Officer (Lab)
# เจ้าหน้าที่ห้องปฎิบัติการ(LAB) -> Laboratory Officer (Lab)
# เชฟ พ่อครัว -> Chef chef
# เทคนิคการแพทย์ -> Medical techniques
# เทคโนโลยีชีวภาพ -> Biotechnology
# เภสัชกร -> pharmacist
# เภสัชกรรม -> pharmacy
# เร่งรัดหนี้สิน -> Accelerate
# เลขานุการ อื่นๆ -> Other secretaries
# เลขานุการ เลขานุการผู้บริหาร -> Secretary of the Executive Secretary
# เลขานุการ/เลขานุการผู้บริหาร -> Secretary / Executive Secretary
# เสื้อผ้า/สิ่งทอ/ช่างแพทเทิร์นอื่นๆ -> Clothing / Textiles / Other patch technicians
# แคชเชียร์ -> cashier
# แผนกรักษาความปลอดภัย -> Security department
# แพทย์ -> physician
# แพทย์/ศัลยแพทย์ -> Doctor / Surgeon
# แพทย์เฉพาะทาง -> Specialist
# แม่บ้าน/พี่เลี้ยง/คนสวน/รปภ.อื่นๆ -> Maid / mentor / garden / other security guard
# แรงงานสัมพันธ์ -> Labor relations
# โฆษณา/สื่อ อื่นๆ -> Advertising / other media
# โทรคมนาคมอื่นๆ -> Other telecommunications
# โปรแกรมเมอร์ -> programmer
# โฟร์แมน -> Fourman
# โภชนาการ -> Nutrition
# โยธา/โครงสร้าง -> Civil / Structure
# ไอทีอื่นๆ -> Other IT
# {'Advertising/Creative': 'Advertising/Creative ', 'Application   Support/ Helpdesk': 'Application   Support/ Helpdesk ', 'Application Network': 'Application Network ', 'BOI': 'Book ', 'Back End Developer': 'Back End Developer ', 'Bancassurance': 'Bancassurance ', 'Brand Marketing': 'Brand Marketing ', 'Brand/Product Marketing': 'Brand/Product Marketing ', 'Business Analyst (BA)': 'Business Analyst (ba) ', 'Business Analyst(BA)': 'Business Analyst (ba) ', 'Call Center': 'Call Center ', 'Computer Graphic/3D/Animation': 'Computer Graphic/3D/Animation ', 'Copy writer': 'Copy writer ', 'Credit Control': 'Credit Control ', 'Data Engineer/Big Data': 'Data Engineer/Big Data ', 'Data Scientist': 'Data Scientist ', 'Database Administration': 'Database Administration ', 'DevOps Engineer': 'DevOps Engineer ', 'Digital Marketing': 'Digital Marketing ', 'E-commerce อื่นๆ': 'Other e-commerce ', 'Full Stack Developer': 'Full Stack Developer ', 'Graphic Design/สิ่งพิมพ์': 'GRAPHIC DESIGN / Paper ', 'Hardware': 'Hardware ', 'IT Audit': 'IT Audit ', 'IT Manager': 'IT Manager ', 'IT Manager/Senior Programmer': 'IT Manager/Senior Programmer ', 'IT Project Manager': 'IT Project Manager ', 'IT Security': 'IT Security ', 'IT Support / Technical Support': 'IT Support / Technical Support ', 'IT Support Help Desk': 'IT Support Help Desk ', 'IT/Admin/Network Admin': 'IT/Admin/Network Admin ', 'MD/CEO': 'MD/CEO ', 'MIS': 'What ', 'Merchandiser': 'Merchandiser ', 'Mobile Application': 'Mobile Application ', 'Network': 'Network ', 'Operation': 'Operation ', 'PR Marketing/Marketing Communications': 'Marketing / Marketing Communications ', 'Part-time/พนักงานสัญญาจ้าง อื่นๆ': 'Part-time / other employees ', 'Pretty/MC': 'Pretty/MC ', 'Programmer': 'Programmer ', 'Programmer/Developer': 'Programmer/Developer ', 'Project Manager(PM)': 'Project Manager(PM) ', 'Retail Banking': 'Retail Banking ', 'SEO': 'THIS ', 'Shipping': 'Shipping ', 'Software Engineer': 'Software Engineer ', 'Software Tester': 'Software tester ', 'Supply Chain': 'Supply Chain ', 'System Admin': 'System Admin ', 'System Analyst': 'System Analyst ', 'System Analyst(SA)': 'System Analyst(SA) ', 'System Engineer and Architect': 'System Engineer and Architect ', 'Sytem Engineer': 'System Engineer ', 'Technical Support/Help Desk': 'Technical Support/Help Desk ', 'Tester': 'Tester ', 'Trading': 'Trading ', 'Treasury': 'Treasury ', 'UX/UI': 'UX / UI ', 'Underwriter': 'Underwriter ', 'Web Content': 'Web Content ', 'Web Content/Web Master': 'Web Content/Web Master ', 'Web Design': 'Web Design ', 'Web Programmer': 'Web programs ', 'Web Programmer/Web Master': 'Web Programs / Web Master ', 'กฎหมาย อื่นๆ': 'Other laws ', 'กราฟฟิค/สื่อสิงพิมพ์/Designer': 'Graphic / Media Singing / Designer ', 'กราฟิกดีไซน์': 'Graphic design ', 'การค้าระหว่างประเทศ': 'International trade ', 'การตลาด': 'Marketing ', 'การตลาดดิจิทัล': 'Digital marketing ', 'การตลาดทั่วไป': 'General marketing ', 'การตลาดอื่นๆ': 'Other marketing ', 'การบิน': 'Aviation ', 'การศึกษา/วิชาการอื่นๆ': 'Education / Other academic ', 'การส่งเสริมการลงทุน(BOI)': 'Investment Promotion (BOI) ', 'การเกษตร/ป่าไม้/ประมง': 'Agriculture / Forestry / Fishing ', 'การเงิน': 'finance ', 'การแพทย์อื่นๆ': 'Other medical ', 'กิจกรรมการตลาด': 'Marketing activities ', 'กุ๊กอาหารไทย/นานาชาติ': 'Thai / International Food Cook ', 'ก่อสร้าง ควบคุมอาคาร': 'Building control construction ', 'ก่อสร้างอื่นๆ': 'Other construction ', 'ขนส่ง/คลังสินค้า อื่นๆ': 'Transport / Other warehouses ', 'ขนส่งสินค้า': 'Cargo ', 'ขับรถทั่วไป': 'General driving ', 'ขับรถส่งเอกสาร ส่งผลิตภัณฑ์': 'Driving, sending documents, sending products ', 'ขับรถส่งเอกสาร/ส่งผลิตภัณฑ์': 'Drive documents / send products ', 'ขาย': 'sell ', 'ขายตรง': 'Direct sale ', 'ขายทางโทรศัพท์': 'Sell by phone ', 'ขายปลีก': 'retail ', 'ขายส่ง': 'wholesale ', 'ขายอื่นๆ': 'Other sales ', 'คนขับรถ อื่นๆ': 'Other drivers ', 'คนขับรถบรรทุก': 'Truck driver ', 'คนขับรถผู้บริหาร': 'Executive driver ', 'คนขับรถรับ-ส่งเอกสาร': 'Driv ...
# Advertising/Creative -> Advertising/Creative
# Application   Support/ Helpdesk -> Application   Support/ Helpdesk
# Application Network -> Application Network
# BOI -> Book
# Back End Developer -> Back End Developer
# Bancassurance -> Bancassurance
# Brand Marketing -> Brand Marketing
# Brand/Product Marketing -> Brand/Product Marketing
# Business Analyst (BA) -> Business Analyst (ba)
# Business Analyst(BA) -> Business Analyst (ba)
# Call Center -> Call Center
# Computer Graphic/3D/Animation -> Computer Graphic/3D/Animation
# Credit Control -> Credit Control
# Data Engineer/Big Data -> Data Engineer/Big Data
# Data Scientist -> Data Scientist
# Database Administration -> Database Administration
# Digital Marketing -> Digital Marketing
# E-commerce อื่นๆ -> Other e-commerce
# Front End Web Developer -> Front End Web Developer
# Graphic Design/สิ่งพิมพ์ -> GRAPHIC DESIGN / Paper
# Hardware -> Hardware
# IT Audit -> IT Audit
# IT Manager -> IT Manager
# IT Manager/Senior Programmer -> IT Manager/Senior Programmer
# IT Project Manager -> IT Project Manager
# IT Security -> IT Security
# IT Support / Technical Support -> IT Support / Technical Support
# IT Support Help Desk -> IT Support Help Desk
# IT/Admin/Network Admin -> IT/Admin/Network Admin
# MD/CEO -> MD/CEO
# MIS -> What
# Merchandiser -> Merchandiser
# Mobile Application -> Mobile Application
# Network -> Network
# Operation -> Operation
# PR Marketing/Marketing Communications -> Marketing / Marketing Communications
# Part-time/พนักงานสัญญาจ้าง อื่นๆ -> Part-time / other employees
# Pretty/MC -> Pretty/MC
# Programmer -> Programmer
# Programmer/Developer -> Programmer/Developer
# Project Manager(PM) -> Project Manager(PM)
# Retail Banking -> Retail Banking
# SEO -> THIS
# Shipping -> Shipping
# Software Engineer -> Software Engineer
# Software Tester -> Software tester
# Supply Chain -> Supply Chain
# System Admin -> System Admin
# System Analyst -> System Analyst
# System Analyst(SA) -> System Analyst(SA)
# System Engineer and Architect -> System Engineer and Architect
# Sytem Engineer -> System Engineer
# Technical Support/Help Desk -> Technical Support/Help Desk
# Tester -> Tester
# Trading -> Trading
# UX/UI -> UX / UI
# Underwriter -> Underwriter
# Web Content -> Web Content
# Web Content/Web Master -> Web Content/Web Master
# Web Design -> Web Design
# Web Programmer -> Web programs
# Web Programmer/Web Master -> Web Programs / Web Master
# call-center -> call-center
# กฎหมาย อื่นๆ -> Other laws
# กราฟิกดีไซน์ -> Graphic design
# การค้าระหว่างประเทศ -> International trade
# การตลาด -> Marketing
# การตลาดดิจิทัล -> Digital marketing
# การตลาดทั่วไป -> General marketing
# การตลาดอื่นๆ -> Other marketing
# การบิน -> Aviation
# การศึกษา/วิชาการอื่นๆ -> Education / Other academic
# การส่งเสริมการลงทุน(BOI) -> Investment Promotion (BOI)
# การเกษตร/ป่าไม้/ประมง -> Agriculture / Forestry / Fishing
# การเงิน -> finance
# การแพทย์อื่นๆ -> Other medical
# กิจกรรมการตลาด -> Marketing activities
# กุ๊กอาหารไทย/นานาชาติ -> Thai / International Food Cook
# ก่อสร้าง ควบคุมอาคาร -> Building control construction
# ก่อสร้างอื่นๆ -> Other construction
# ขนส่ง/คลังสินค้า อื่นๆ -> Transport / Other warehouses
# ขนส่งสินค้า -> Cargo
# ขับรถส่งเอกสาร ส่งผลิตภัณฑ์ -> Driving, sending documents, sending products
# ขับรถส่งเอกสาร/ส่งผลิตภัณฑ์ -> Drive documents / send products
# ขาย -> sell
# ขายทางโทรศัพท์ -> Sell by phone
# ขายปลีก -> retail
# ขายส่ง -> wholesale
# ขายอื่นๆ -> Other sales
# คนขับรถ อื่นๆ -> Other drivers
# คนขับรถบรรทุก -> Truck driver
# คนขับรถผู้บริหาร -> Executive driver
# คนขับรถรับ-ส่งเอกสาร -> Driver - Document delivery
# คนขับรถส่งสินค้า -> Driver
# คนสวน -> Gardener
# ครีเอทีฟ -> Creative
# ครู -> teacher
# คลังสินค้า -> warehouse
# คลังสินค้า - จัดเก็บ -> Warehouse - Storage
# ควบคุมคุณภาพ/QC/QA/QM -> Quality control / QC / QA / QM
# ควบคุมดูแลเครื่องจักร -> Supervise the machine
# ความงาม -> Beauty
# คีย์ข้อมูล -> Data key
# งาน Application Network -> Application Network
# งาน Copy Writer -> Copy writer
# งาน Hardware -> Hardware
# งาน IT Project -> IT Project
# งาน IT Security -> IT Security
# งาน IT Support -> Support
# งาน Sales Engineer -> Sales Engineer
# งาน Software -> Software
# งาน Software Tester -> Software Tester
# งานกฎหมาย -> Legal work
# งานกราฟิก -> Graphic
# งานการตลาดดิจิทัล -> Digital marketing work
# งานการตลาดทั่วไป -> General marketing work
# งานการเงิน -> Finance work
# งานขนส่ง -> Transportation
# งานขาย -> Sale
# งานขายตรง -> Direct sales
# งานขายปลีก -> Retail
# งานคลังสินค้า -> Warehouse
# งานจัดซื้อ งานจัดหา -> Procurement
# งานจัดซื้ออุตสาหกรรม -> Industrial procurement
# งานตรวจสอบคุณภาพ -> Quality inspection
# งานตรวจสอบบัญชี -> Audit
# งานต้อนรับลูกค้า -> Customer welcoming
# งานที่ปรึกษาการเงินลูกค้าองค์กร -> Corporate Finance Advisor
# งานธนาคารอื่นๆ -> Other banking work
# งานธุรการ งานการจัดการทั่วไป -> Administration, general management
# งานธุรการบัญชี -> Account administration
# งานนำเข้า-ส่งออก -> Import-export
# งานบริการด้านการเงิน -> Financial services
# งานบริการลูกค้า -> Customer service
# งานบริหารค่าจ้าง งานบริหารผลตอบแทน -> Wage management Return Management
# งานบริหารทั่วไป -> General management
# งานบริหารอสังหาริมทรัพย์ -> Real Estate Management
# งานบัญชี -> Accounting
# งานบัญชีทั่วไป -> General Accounting
# งานบัญชีภาษีอากร -> Taxation
# งานบัญชีรับ-จ่าย -> Accounting
# งานบัญชีลูกหนี้-เจ้าหนี้ -> Accounts Receivables - Creditors
# งานบัญชีอื่นๆ -> Other accounting
# งานประชาสัมพันธ์ทั่วไป -> General public relations
# งานผลิตทั่วไป -> General production
# งานผลิตอื่นๆ -> Other production
# งานผลิตเสื้อผ้า สิ่งทอ -> Textile clothing
# งานฝึกอบรม -> Training
# งานพัฒนาธุรกิจ -> Business development
# งานวางกลยุทธ์การโฆษณา -> Advertising strategy
# งานวางแผนการผลิต งานควบคุมการผลิต -> Production planning Production control
# งานวิจัย งานพัฒนา -> Research, development
# งานวิศวกรซ่อมบำรุง -> Maintenance Engineer
# งานวิศวกรเครื่องกล -> Mechanical Engineer
# งานวิศวกรไฟฟ้า งานวิศวกรอิเล็กทรอนิกส์ -> Electrical engineer Electronics Engineer
# งานวิเคราะห์การลงทุน-กองทุน -> Investment Analysis - Fund
# งานว่าจ้างและเงินเดือน -> Hiring and salary
# งานสินเชื่อ-วิเคราะห์สินเชื่อ -> Loan - Credit Analysis
# งานสื่อสารการตลาด -> Marketing Communication
# งานส่งออก งานนำเข้า -> Import-export
# งานอีคอมเมิร์ซอื่นๆ -> Other e-commerce work
# งานอื่นๆ -> Other jobs
# งานเคมี -> Chemical
# งานเทคนิคการแพทย์ -> Medical Technology
# งานเร่งรัดหนี้สิน -> Debt collection work
# งานเลขานุการ งาน Personal Assistant -> Secretary of Personal Assistant
# งานโปรแกรมเมอร์ -> Programmer
# จองห้อง/จองตั๋ว/Tour Operations -> Booking / Booking Ticket / Tour Operations
# จัดซื้อ -> Purchase
# จัดซื้อ จัดหา -> Purchasing
# จัดซื้อ/จัดหา -> Purchasing / Procurement
# จัดซื้ออื่นๆ -> Other purchasing
# จัดซื้ออุตสาหกรรม -> Purchase industry
# จัดซื้อเครื่องใช้ในครัวเรือน -> Purchase household appliances
# จัดซื้อเสื้อผ้า -> Purchase clothes
# จัดเก็บ -> Store
# ชีววิทยา -> biology
# ช่าง Jewelry/ทอง/เงิน -> Jewelry / gold / silver
# ช่าง/คนงานทั่วไป -> Mechanic / General workers
# ช่างCNC/Mold/กลึง/เจียระไน -> CNC / MOLD / Lathe / uncut
# ช่างCNC/กลึง/เจียระไน -> CNC technician / turning / uncut
# ช่างซ่อมบำรุง -> Maintenance
# ช่างฝีมือ -> Craftsman
# ช่างพิมพ์ -> Print technician
# ช่างภาพ -> Photographer
# ช่างภาพ/ตัดต่อ -> Photographer / Montage
# ช่างยนต์/ช่างกลโรงงาน -> Mechanic / Mechanic Factory
# ช่างศิลป์(Sculpture/Print/Paint/Drawing) -> SCULPTURE / PRINT / PAINT / DRAWING)
# ช่างเทคนิค -> Technician
# ช่างเทคนิค/อิเลคโทรนิคอื่นๆ -> Other technicians / electronic technicians
# ช่างแพทเทิร์น/มาร์ก/ตัดผ้า -> Pattern Pattern / Mark / Cutting Cloth
# ช่างและคนงานก่อสร้าง -> Mechanic and construction workers
# ช่างไฟฟ้า/อิเลคโทรนิค/คอมพิวเตอร์/สื่อสาร -> Electrician / Electronic / Computer / Communication
# ดูแลระบบ Network -> Network administration
# ดูแลเว็บไซต์ และ SEO -> Take care of websites and SEO
# ตรวจสอบคุณภาพ -> Quality inspection
# ตรวจสอบคุณภาพ /QC/QA/QM/ISO -> Quality inspection / QC / QA / QM / ISO
# ตรวจสอบคุณภาพอัญมณี -> Check the gem light quality
# ตรวจสอบบัญชี -> Check account
# ตรวจสอบอาคาร/สำรวจ -> Building inspection / exploration
# ตัวแทนประกันภัย -> Insurance agent
# ต้อนรับลูกค้า -> Welcome customers
# ทนายความ -> lawyer
# ทันตแพทย์ -> dentist
# ทัวร์/บริษัททัวร์ -> Tour / Tour Company
# ที่ปรึกษาด้านกฎหมาย -> Legal consultant
# ที่ปรึกษาทางการเงิน -> Financial advisor
# ที่ปรึกษาอสังหาริมทรัพย์ -> Real estate consultant
# ที่ปรึกษาไอที -> IT consultant
# ท่องเที่ยวอื่นๆ -> Other travel
# ธนาคาร/การเงินอื่นๆ -> Bank / Other Finance
# ธรณีวิทยาและป่าไม้อื่นๆ -> Other geology and forests
# ธุรการ/การจัดการทั่วไป -> Administration / General management
# ธุรการทั่วไป -> General Administration
# ธุรการบัญชี -> Accounting Administration
# ธุรการฝ่ายขาย -> Sales Administration
# ธุรการอื่นๆ/การจัดการทั่วไปอื่นๆ -> Other administrative / other general management
# ธุรกิจการบิน -> Aviation business
# นักกฎหมาย -> Lawyer
# นักกายภาพบำบัด -> Physical therapist
# นักข่าว -> journalist
# นักคณิตศาสตร์/สถิติ -> Mathematician / Statistics
# นักปฐพี -> Gate
# นักวิจัยและพัฒนาผลิตภัณฑ์ -> Product research and development
# นักวิทยาศาสตร์/เคมี/ชีวะ/ฟิสิกส์ -> Scientists / Chemistry / Chemical / Physics
# นักวิเคราะห์/เศรษฐศาสตร์ อื่นๆ -> Analyst / other economics
# นักศึกษาจบใหม่ -> New graduate student
# นักศึกษาฝึกงาน -> Internship students
# นักสถิติการประกันภัย -> Insurance statistics
# นักออกแบบ UI/UX -> UI / UX designer
# นักออกแบบ UX/UI -> UX / UI designer
# นักเขียน -> Writer
# นักเขียน/นักแปลภาษา -> Writer / Translator
# นักเขียน/บรรณาธิการ/นักแปลภาษา อื่นๆ -> Writer / Editor / Other translators
# นักแปลภาษา -> Language translator
# นิติกร -> lawyer
# บรรณาธิการ -> editor
# บรรณารักษ์ -> librarian
# บริการ/ลูกค้าสัมพันธ์/Call Center อื่นๆ -> Services / Customer Relations / Call Center
# บริการด้านการเงิน -> Financial services
# บริการทั่วไป -> General service
# บริการลูกค้า ลูกค้าสัมพันธ์ -> Customer service customer service
# บริการลูกค้า/ลูกค้าสัมพันธ์(CRM) -> Customer Service / Customer Service (CRM)
# บริการสังคม -> Social Services
# บริหารการขาย -> Sales management
# บริหารการขาย/SE -> Sales / SE
# บริหารการตลาด -> Marketing Management
# บริหารการผลิต -> Production management
# บริหารการโรงแรม/รีสอร์ท/ท่องเที่ยว -> Hotel / Resort / Travel Management
# บริหารค่าจ้าง บริหารผลตอบแทน -> Manage wages Return management
# บริหารงานอีเวนท์ -> Event management
# บริหารทั่วไป -> General administration
# บริหารสินทรัพย์ -> Asset Management
# บริหารอสังหาริมทรัพย์ -> Real Estate Management
# บริหารแบรนด์สินค้า ตราสินค้า ผลิตภัณฑ์ -> Brand management, brand products
# บัญชี -> account
# บัญชีภาษีอากร -> Tax account
# บัญชีรับ-จ่าย -> Account
# บัญชีลูกหนี้-เจ้าหนี้ -> Accounts receivable - creditors
# บัญชีอื่นๆ -> Other accounts
# บันเทิง/นักแสดง/นักร้อง อื่นๆ -> Entertainment / Actress / Other singers
# บาริสต้า -> Barista
# บาร์เทนเดอร์ -> Bartender
# บุคคล/ฝึกอบรมอื่นๆ -> Person / other training
# ประกันภัยอื่นๆ -> Other insurance
# ประชาสัมพันธ์ทั่วไป -> General public relations
# ประสานงานขาย -> Coordinate sales
# ประสานงานทั่วไป -> General coordination
# ประเมินราคา -> Appraise
# ปรึกษาการขาย -> Sales consultation
# ป้อนข้อมูล -> Input
# ผลิตทั่วไป -> General production
# ผลิตสื่อ -> Media production
# ผลิตอัญมณี เครื่องประดับ -> Manufacture of jewelry
# ผลิตอื่นๆ -> Other production
# ผลิตเสื้อผ้า สิ่งทอ -> Production of textiles
# ผู้จัดการทั่วไป -> General manager
# ผู้จัดการฝึกหัด -> Trainer
# ผู้จัดการฝ่าย -> Manager
# ผู้จัดการฝ่ายการเงิน/CFO -> Finance Manager / CFO
# ผู้จัดการฝ่ายขาย -> Sales manager
# ผู้จัดการร้าน -> Shop manager
# ผู้จัดการสาขา -> Branch manager
# ผู้จัดการแผนก -> Department manager
# ผู้จัดการโรงงาน -> Factory manager
# ผู้ช่วยกุ๊ก -> Assistant
# ผู้ช่วยทางการแพทย์ -> Medical assistant
# ผู้ช่วยผู้จัดการ -> Assistant
# ผู้ช่วยผู้จัดการสาขา -> Assistant Branch Manager
# ผู้ช่วยเลขานุการ -> Secretary assistant
# ผู้ช่วยในครัว -> Kitchen assistant
# ผู้ดูแลระบบเครือข่าย -> Network administrator
# ผู้ดูแลระบบโทรคมนาคม -> Telecommunications administrator
# ผู้ดูแลและแก้ไขระบบโทรคมนาคม -> Telecommunications and editing systems
# ผู้บริหารระดับสูง -> High-level executives
# ผู้บริหารโครงการ -> Project Manager
# ผู้อำนวยการ/รองผู้อำนวยการ -> Director / Deputy Director
# ฝึกอบรม -> Train
# ฝ่ายผลิต/โรงงาน -> Production / Factory
# พนักงาน แผนกตรวจรับสินค้า/สต็อกรูม -> Employees, department, receiving goods / collection stock
# พนักงาน แผนกพื้นที่เช่า และศูนย์อาหาร -> Staff, department, rental area And food centers
# พนักงาน แผนกสินค้าทั่วไป -> General product department staff
# พนักงาน แผนกอาหารสด/อาหารแห้ง -> Fresh food department staff / dried food
# พนักงานPart-time -> Part-time employees
# พนักงานPart-time(รายวัน/รายชั่วโมง) -> Part-time employees (daily / hourly)
# พนักงานขับรถ/ขับรถผู้บริหาร -> Driver / Driving Executive
# พนักงานขาย -> Salesperson
# พนักงานขาย/Sales/AE -> Salesman / Sales / AE
# พนักงานขายทางโทรศัพท์ -> Telephone
# พนักงานขายทางโทรศัพท์/Telesales -> Telephone sales staff / telesales
# พนักงานชั่วคราว(Temporary) -> Temporary staff
# พนักงานดูแลลานจอดรถ -> Staff take care of the parking lot
# พนักงานต้อนรับ -> Receptionist
# พนักงานทำความสะอาด แม่บ้าน -> Maid cleaning staff
# พนักงานทำความสะอาด/แม่บ้าน -> Cleaning staff / housewife
# พนักงานฝ่ายบุคคล -> Individual
# พนักงานฝ่ายบุคคล (HR) -> Personnel (HR)
# พนักงานฝ่ายบุคคล(HR) -> Personnel (HR)
# พนักงานร้านกาแฟ/Barista -> Coffee shop staff / Barista
# พนักงานล้างจาน -> Dishwasher
# พนักงานสัญญาจ้าง -> Employment employee
# พนักงานเขียนแบบ/AutoCad/Draftman -> Staff / AutoCAD / Draftman
# พนักงานเสิร์ฟ -> Waiter
# พนักงานแนะนำสินค้า (PC) -> Product Introduction (PC)
# พนักงานแนะนำสินค้าประจำร้าน/PC -> Staff in the shop / PC
# พนักงานแผนกบริการลูกค้า/แคชเชียร์ -> Customer service staff / cashier
# พนักงานโรงงานเสื้อผ้า/สิ่งทอ -> Factory / Textile factory
# พยาบาล -> nurse
# พลังงาน ทรัพยากรธรรมชาติ น้ำมันและก๊าซ -> Natural resource energy Oil and gas
# พัฒนาธุรกิจ -> Business development
# พัฒนาธุรกิจและพัฒนาองค์กร อื่นๆ -> Business development and other organizational development
# พัฒนาผลิตภัณฑ์ -> Product development
# พัฒนาองค์กร -> Organization development
# พัฒนาองค์กร/ISO -> Organization Development / ISO
# พิธีกร ผู้ประกาศ / MC -> MC announcer / MC
# พิมพ์ -> print
# พิสูจน์อักษร -> Proofread
# พี่เลี้ยงเด็ก -> Babysitter
# พื้นที่/แลนด์สเคป -> Area / Landscape
# ฟิสิกส์ -> physics
# ภูมิศาสตร์/แผนที่/GIS/ผังเมือง อื่นๆ -> Geography / Map / GIS / Other city plan
# ภูมิสถาปัตย์ -> Landscape architecture
# มนุษยศาสตร์/ล่าม อื่นๆ -> Humanities / Other Interpreters
# มัคคุเทศก์ -> guide
# มัคคุเทศก์/จองห้อง/จองตั๋ว อื่นๆ -> Guide / Booking Room / Booking other tickets
# มัณฑนากร -> Decorator
# รัฐศาสตร์การปกครอง -> Political Science
# ราชการ -> service
# ราชการ/บริการสาธารณะ อื่นๆ -> Government / other public services
# ลงทุน -> invest
# ล่าม/นักแปล -> Interpreter / Translator
# ล่ามภาษาจีน -> Chinese interpreter
# ล่ามภาษาญี่ปุ่น -> Japanese interpreter
# ล่ามภาษาอังกฤษ -> English interpreter
# วางกลยุทธ์การโฆษณา -> Place advertising strategies
# วางแผนการผลิต -> Production plan
# วางแผนการผลิต/ควบคุมการผลิต -> Production / Production Control Planning
# วิจัย/วิเคราะห์การตลาด -> Research / Marketing Analysis
# วิจัยการตลาด -> Market Research
# วิจัยตลาด -> Market research
# วิจัยและพัฒนา -> Research and development
# วิทยาศาสตร์ /Lab/วิจัยและพัฒนา อื่นๆ -> Science / Lab / Other research and development
# วิทยาศาสตร์การกีฬา -> Sports science
# วิทยาศาสตร์การอาหาร -> Food science
# วิทยาศาสตร์การอาหาร (Food Science) -> Food Science
# วิทยาศาสตร์สิ่งแวดล้อม -> Environmental science
# วิทยุโทรทัศน์ -> Television
# วิศวกรการผลิต -> Production engineer
# วิศวกรการผลิต/วิศวกรโรงงาน -> Production Engineer / Factory Engineer
# วิศวกรขาย -> Sales engineer
# วิศวกรคอมพิวเตอร์ -> Computer engineer
# วิศวกรชีวการแพทย์ -> Biomedical Engineer
# วิศวกรซ่อมบำรุง -> Maintenance engineer
# วิศวกรบำรุงรักษา -> Maintenance engineer
# วิศวกรประเมินราคา -> Evaluation engineer
# วิศวกรพลังงาน -> Energy engineer
# วิศวกรพอลิเมอร์ -> Polymer engineer
# วิศวกรยานยนต์ -> Automotive Engineer
# วิศวกรรมงานระบบประกอบอาคาร -> Engineering building system
# วิศวกรรมอุตสาหการ -> Industrial engineering
# วิศวกรรมเคมี -> Chemical Engineering
# วิศวกรสำรวจ -> Explore engineer
# วิศวกรสิ่งแวดล้อม -> Environmental engineer
# วิศวกรสื่อสาร -> Communication engineer
# วิศวกรออกแบบ -> Design engineer
# วิศวกรอุตสาหการ/โรงงาน -> Industrial Engineer / Factory
# วิศวกรเขียนแบบ -> Write engineer
# วิศวกรเคมี/ปิโตรเลียม -> Chemical / Petroleum Engineer
# วิศวกรเครื่องกล -> Mechanical engineer
# วิศวกรเครื่องกล/ยานยนต์ -> Mechanical / Automotive Engineer
# วิศวกรเทคโนโลยีขนถ่ายวัสดุ -> Material handling technology engineer
# วิศวกรเหมืองแร่ -> Mining engineer
# วิศวกรแมคคาทรอนิกส์ -> Machatronics Engineer
# วิศวกรโครงการ -> Project Engineer
# วิศวกรโทรคมนาคม -> Telecommunications engineer
# วิศวกรโยธา -> Civil Engineer
# วิศวกรโยธา/ก่อสร้าง -> Civil / Construction Engineer
# วิศวกรโลหะการ -> Metal engineers
# วิศวกรไฟฟ้า/วิศวกรอิเล็กทรอนิกส์ -> Electrical Engineer / Electronics Engineer
# วิศวกรไฟฟ้า/อิเลคโทรนิค/สื่อสาร -> Electrical / Electronic Engineer / Communication
# วิศวะอื่นๆ -> Other engineering
# วิเคราะห์การลงทุน -> Investment analysis
# วิเคราะห์ข้อมูลทั่วไป -> General information analysis
# วิเคราะห์สถิติ -> Statistical analysis
# วิเคราะห์สินเชื่อ/อนุมัติสินเชื่อ -> Credit analysis / Credit approval
# ว่าจ้างและเงินเดือน -> Hiring and salary
# สถาปนิก -> architect
# สถาปนิก / มัณฑนากร อื่นๆ -> Architects / Other decorations
# สถาปัตยกรรม -> architecture
# สถาปัตยกรรมภายในและมัณฑนศิลป์ -> Interior architecture and decorative arts
# สปาบำบัด/ฟิตเนส/กีฬา/สันทนาการ -> Spa Therapy / Fitness / Sport / Recreation
# สรรหาบุคลากร -> Recruit
# สหกิจศึกษา -> Cooperative Education
# สอนพิเศษ/ติวเตอร์ -> Tutorial / Tutor
# สัตวแพทย์ -> veterinary
# สัตวแพทย์/สัตวบาล -> Veterinary / animal husbandry
# สำรวจ -> survey
# สินเชื่อ -> Loan
# สื่อสารการตลาด -> Marketing communication
# สื่อสิ่งพิมพ์ -> Publication
# สุขภาพ -> health
# สุขภาพ /โภชนาการ/ความงาม อื่นๆ -> Health / Nutrition / Other beauty
# ส่งออก/นำเข้า -> Export / Import
# หัวหน้า/ผู้จัดการ/ผู้บริหาร -> Chief / Manager / Manager
# หัวหน้า/ผู้จัดการ/ผู้บริหาร อื่นๆ -> Chief / Manager / Other Manager
# อสังหาริมทรัพย์อื่นๆ -> Other real estate
# ออกแบบ/เขียนแบบ/กราฟฟิค/ช่างภาพ อื่นๆ -> Design / Write / Graphic / Other photographers
# ออกแบบกราฟิก -> Graphic design
# ออกแบบการจัดวางสินค้า -> Product placement design
# ออกแบบตกแต่งภายใน -> Interior design
# ออกแบบผลิตภัณฑ์/ออกแบบบรรจุภัณฑ์ -> Product design / packaging design
# ออกแบบมัลติมีเดีย -> Multimedia design
# ออกแบบลายผ้า/เสื้อผ้า -> Striped fabric design / clothing
# ออกแบบสิ่งพิมพ์ -> Publication design
# ออกแบบเครื่องประดับ -> Jewelry design
# ออกแบบเว็บไซต์ - Design -> Website Design - Design
# ออกแบบแฟชั่น/ดีไซน์เนอร์ -> Fashion design / designer
# ออแกไนซ์/อีเว้นท์ -> Organization / Event
# อัญมณีและเครื่องประดับอื่นๆ -> Other gems and jewelry
# อาจารย์ -> professor
# อาหาร/เครื่องดื่ม/กุ๊ก/บาร์เทนเดอร์/พนักงานเสิร์ฟอื่นๆ -> Food / Beverage / Cook / Bartender / Other waiters
# อาหารและเครื่องดื่ม -> Food and drink
# อีเว้นท์ -> Event
# อื่นๆ -> Other
# เคมี -> chemical
# เจ้าหน้าที่ความปลอดภัย -> Safety officer
# เจ้าหน้าที่ความปลอดภัย(จป.) -> Safety Officer (Chor.)
# เจ้าหน้าที่ความปลอดภัย(จป.)/สิ่งแวดล้อม อื่นๆ -> Safety Officer (Chor.) / Other Environment
# เจ้าหน้าที่ดูแลลูกค้า (Teller) -> Customer care staff (Teller)
# เจ้าหน้าที่ตรวจสอบทุจริต -> Fraud
# เจ้าหน้าที่ตรวจสอบภายใน -> Internal Audit Officer
# เจ้าหน้าที่ที่ดิน -> Landman
# เจ้าหน้าที่ป้องกันการสูญเสีย -> Defense staff
# เจ้าหน้าที่ฝึกอบรม/วิทยากร -> Training staff / speaker
# เจ้าหน้าที่รักษาความปลอดภัย/รปภ. -> Security Officer / Security Center
# เจ้าหน้าที่วิเคราะห์ข้อมูล -> Data analysis officer
# เจ้าหน้าที่สินไหมทดแทน -> Claims Officer
# เจ้าหน้าที่สิ่งแวดล้อม -> Environmental staff
# เจ้าหน้าที่ห้องปฎิบัติการ (Lab) -> Laboratory Officer (Lab)
# เจ้าหน้าที่ห้องปฎิบัติการ(LAB) -> Laboratory Officer (Lab)
# เชฟ พ่อครัว -> Chef chef
# เทคนิคการแพทย์ -> Medical techniques
# เทคโนโลยีชีวภาพ -> Biotechnology
# เภสัชกร -> pharmacist
# เภสัชกรรม -> pharmacy
# เร่งรัดหนี้สิน -> Accelerate
# เลขานุการ อื่นๆ -> Other secretaries
# เลขานุการ/เลขานุการผู้บริหาร -> Secretary / Executive Secretary
# เสื้อผ้า/สิ่งทอ/ช่างแพทเทิร์นอื่นๆ -> Clothing / Textiles / Other patch technicians
# แคชเชียร์ -> cashier
# แคดดี้ (caddy) -> Caddy
# แผนกรักษาความปลอดภัย -> Security department
# แพทย์ -> physician
# แพทย์เฉพาะทาง -> Specialist
# แม่บ้าน/พี่เลี้ยง/คนสวน/รปภ.อื่นๆ -> Maid / mentor / garden / other security guard
# แรงงานสัมพันธ์ -> Labor relations
# โฆษณา/สื่อ อื่นๆ -> Advertising / other media
# โทรคมนาคมอื่นๆ -> Other telecommunications
# โปรแกรมเมอร์ -> programmer
# โฟร์แมน -> Fourman
# โภชนาการ -> Nutrition
# โยธา/โครงสร้าง -> Civil / Structure
# ไอทีอื่นๆ -> Other IT
# {'Advertising/Creative': 'Advertising/Creative ', 'Application   Support/ Helpdesk': 'Application   Support/ Helpdesk ', 'Application Network': 'Application Network ', 'BOI': 'Book ', 'Back End Developer': 'Back End Developer ', 'Bancassurance': 'Bancassurance ', 'Brand Marketing': 'Brand Marketing ', 'Brand/Product Marketing': 'Brand/Product Marketing ', 'Business Analyst (BA)': 'Business Analyst (ba) ', 'Business Analyst(BA)': 'Business Analyst (ba) ', 'Call Center': 'Call Center ', 'Computer Graphic/3D/Animation': 'Computer Graphic/3D/Animation ', 'Credit Control': 'Credit Control ', 'Data Engineer/Big Data': 'Data Engineer/Big Data ', 'Data Scientist': 'Data Scientist ', 'Database Administration': 'Database Administration ', 'Digital Marketing': 'Digital Marketing ', 'E-commerce อื่นๆ': 'Other e-commerce ', 'Front End Web Developer': 'Front End Web Developer ', 'Graphic Design/สิ่งพิมพ์': 'GRAPHIC DESIGN / Paper ', 'Hardware': 'Hardware ', 'IT Audit': 'IT Audit ', 'IT Manager': 'IT Manager ', 'IT Manager/Senior Programmer': 'IT Manager/Senior Programmer ', 'IT Project Manager': 'IT Project Manager ', 'IT Security': 'IT Security ', 'IT Support / Technical Support': 'IT Support / Technical Support ', 'IT Support Help Desk': 'IT Support Help Desk ', 'IT/Admin/Network Admin': 'IT/Admin/Network Admin ', 'MD/CEO': 'MD/CEO ', 'MIS': 'What ', 'Merchandiser': 'Merchandiser ', 'Mobile Application': 'Mobile Application ', 'Network': 'Network ', 'Operation': 'Operation ', 'PR Marketing/Marketing Communications': 'Marketing / Marketing Communications ', 'Part-time/พนักงานสัญญาจ้าง อื่นๆ': 'Part-time / other employees ', 'Pretty/MC': 'Pretty/MC ', 'Programmer': 'Programmer ', 'Programmer/Developer': 'Programmer/Developer ', 'Project Manager(PM)': 'Project Manager(PM) ', 'Retail Banking': 'Retail Banking ', 'SEO': 'THIS ', 'Shipping': 'Shipping ', 'Software Engineer': 'Software Engineer ', 'Software Tester': 'Software tester ', 'Supply Chain': 'Supply Chain ', 'System Admin': 'System Admin ', 'System Analyst': 'System Analyst ', 'System Analyst(SA)': 'System Analyst(SA) ', 'System Engineer and Architect': 'System Engineer and Architect ', 'Sytem Engineer': 'System Engineer ', 'Technical Support/Help Desk': 'Technical Support/Help Desk ', 'Tester': 'Tester ', 'Trading': 'Trading ', 'UX/UI': 'UX / UI ', 'Underwriter': 'Underwriter ', 'Web Content': 'Web Content ', 'Web Content/Web Master': 'Web Content/Web Master ', 'Web Design': 'Web Design ', 'Web Programmer': 'Web programs ', 'Web Programmer/Web Master': 'Web Programs / Web Master ', 'call-center': 'call-center ', 'กฎหมาย อื่นๆ': 'Other laws ', 'กราฟิกดีไซน์': 'Graphic design ', 'การค้าระหว่างประเทศ': 'International trade ', 'การตลาด': 'Marketing ', 'การตลาดดิจิทัล': 'Digital marketing ', 'การตลาดทั่วไป': 'General marketing ', 'การตลาดอื่นๆ': 'Other marketing ', 'การบิน': 'Aviation ', 'การศึกษา/วิชาการอื่นๆ': 'Education / Other academic ', 'การส่งเสริมการลงทุน(BOI)': 'Investment Promotion (BOI) ', 'การเกษตร/ป่าไม้/ประมง': 'Agriculture / Forestry / Fishing ', 'การเงิน': 'finance ', 'การแพทย์อื่นๆ': 'Other medical ', 'กิจกรรมการตลาด': 'Marketing activities ', 'กุ๊กอาหารไทย/นานาชาติ': 'Thai / International Food Cook ', 'ก่อสร้าง ควบคุมอาคาร': 'Building control construction ', 'ก่อสร้างอื่นๆ': 'Other construction ', 'ขนส่ง/คลังสินค้า อื่นๆ': 'Transport / Other warehouses ', 'ขนส่งสินค้า': 'Cargo ', 'ขับรถส่งเอกสาร ส่งผลิตภัณฑ์': 'Driving, sending documents, sending products ', 'ขับรถส่งเอกสาร/ส่งผลิตภัณฑ์': 'Drive documents / send products ', 'ขาย': 'sell ', 'ขายทางโทรศัพท์': 'Sell by phone ', 'ขายปลีก': 'retail ', 'ขายส่ง': 'wholesale ', 'ขายอื่นๆ': 'Other sales ', 'คนขับรถ อื่นๆ': 'Other drivers ', 'คนขับรถบรรทุก': 'Truck driver ', 'คนขับรถผู้บริหาร': 'Executive driver ', 'คนขับรถรับ-ส่งเอกสาร': 'Driver - Document delivery ', 'คนขับรถส่งสินค้า': 'Driver ', 'คนสวน': 'Gardener ', 'ครีเอทีฟ': 'Creative ', 'ครู': 'teacher ', 'คลังสินค้า': 'warehouse ', 'คลังสินค้า - จัดเก็บ': 'Warehouse - Sto ...

# %% [markdown]
# &ensp;
#
# For the 'province' column, the 'ThaiAddressParser' library is applied to extract location information. This is also effortless to translate in to English language.

# %%
import ThaiAddressParser

def FindProvince(df):
    provinces = []
    for row in df:
        try:
            provinces.append(ThaiAddressParser.parse(row)['province']['en'])
        except:
            provinces.append('')

    return provinces

# %%
active = active.dropna(subset=['location'])
previous = previous.dropna(subset=['location'])


previous['location'] = previous['location'].astype('str')
active['location'] = active['location'].astype('str')

previous['province'] = FindProvince(previous['location'])
active['province'] = FindProvince(active['location'])

previous = previous.dropna(subset=['province'])
active = active.dropna(subset=['province'])

# %%
def clean_role_name(df):
    df = df.str.split("/", n = 1, expand = True)[0]
    df = df.str.lower()
    df = df.str.strip()
    return df

# %%
all_data = pd.concat([previous, active])

all_data.dropna(subset=['role_name', 'sub_role_name', 'company_name', 'province'], inplace=True)
all_data = all_data[~all_data.province.str.contains("Nan")]

all_data['role_name'] = clean_role_name(all_data['role_name'])

all_data['sub_role_name'] = clean_role_name(all_data['sub_role_name'])

# %% [markdown]
# &ensp;
#
# After cleaning white spaces, lowering character cases, and selecting only first element from name with '/', it is matching process. Some role names may have same position or job but they spelled differently such as 'account' and 'accounting'. To tackle down this problem, 'fuzzywuzzy' library is implemented.
#
# ## FuzzyWuzzy
#
# FuzzyWuzzy is a library of Python which is used for string matching. Fuzzy string matching is the process of finding strings that match a given pattern. Basically it uses Levenshtein Distance to calculate the differences between sequences.

# %%
from fuzzywuzzy import process

def matching_process(df):
    role_dict = {}
    roles = sorted(df.unique())
    for n,role in enumerate(roles):
        print(str(n) +" " + role)
        if len(role)>= 5:
            matches = process.extract(role, df.unique(), limit = len(df.unique()))
            for match in matches:
              # Check whether the similarity score is greater than or equal to 80
              if match[1] >= 90 and len(match[0])>=5 and match[1] < 100:
                if len(match[0]) < len(role):
                    print(match[0] + " -> " + role + ": " +str(match[1]))
                    role_dict[match[0]] = role
                else:
                    print(role + " -> " + match[0] + ": " + str(match[1]))
                    role_dict[role] = match[0]
    print(role_dict)
    return (role_dict)

# %%
roles = matching_process(all_data['role_name'])


# There are sensitive case that have to manually eliminate as fuzzywuzzy may not correctly match in some cases.

del roles["administration"]
del roles["design"]

roles['warehouse'] = 'transportation - warehouse'
roles['transport and warehouse'] = 'transportation - warehouse'
roles['banking banking '] = 'bank'

all_data['role_name'] = all_data['role_name'].replace(roles)
all_data['sub_role_name'] = all_data['sub_role_name'].replace(roles)
# Out:
# 0 account
# 1 accounting
# 2 administration
# administration -> human resources administration: 90
# 3 advertising
# 4 analyst
# 5 architect
# 6 art
# 7 aviation business
# 8 bank
# 9 banking banking
# 10 beauty service
# 11 business development and organization development
# 12 civil
# 13 cleanliness and garden
# 14 clothing
# 15 computer
# 16 construction
# 17 customer service
# customer service -> customer service-call center: 90
# customer service -> customer service sales business development: 90
# 18 customer service sales business development
# customer service -> customer service sales business development: 90
# 19 customer service-call center
# customer service -> customer service-call center: 90
# 20 debt staff
# 21 department store
# 22 design
# design -> website design: 90
# 23 doctors
# 24 drawing
# 25 drive
# 26 drivers
# 27 e-commerce
# ecommerce -> e-commerce: 95
# 28 ecommerce
# ecommerce -> e-commerce: 95
# 29 education
# 30 engineer
# 31 engineering
# 32 entertainment
# 33 factory
# 34 finance - bank
# 35 food
# 36 freelance
# 37 gems and jewelry
# 38 geography
# 39 geology and forest
# 40 government
# 41 guide
# 42 health
# health -> health jobs, nutrition, beauty: 90
# 43 health jobs, nutrition, beauty
# health -> health jobs, nutrition, beauty: 90
# 44 human resources administration
# administration -> human resources administration: 90
# 45 humanities
# 46 import-export
# 47 insurance
# 48 interpreter
# 49 it
# 50 it jobs
# 51 jobs in restaurants and beverages
# 52 law
# 53 maid
# 54 management
# 55 manager
# 56 marketing
# marketing -> marketing jobs pr: 90
# 57 marketing jobs pr
# marketing -> marketing jobs pr: 90
# 58 mechanic
# 59 media work
# 60 medical
# medical -> medical services: 90
# 61 medical services
# medical -> medical services: 90
# 62 other
# other -> other jobs: 90
# 63 other jobs
# other -> other jobs: 90
# 64 part-time employment contract
# 65 part-time work
# 66 person
# 67 produce
# 68 production
# production -> production work: 90
# 69 production work
# production -> production work: 90
# 70 purchase
# 71 purchasing
# 72 real estate
# 73 research
# research -> science, lab, research and development: 90
# 74 safety officer
# 75 science
# science -> science, lab, research and development: 90
# 76 science, lab, research and development
# science -> science, lab, research and development: 90
# research -> science, lab, research and development: 90
# 77 secretary
# 78 sell
# 79 send documents
# 80 specialized services
# 81 technician
# 82 telecommunications
# 83 transport
# transport -> transportation - warehouse: 90
# transport -> transportation: 90
# 84 transportation
# transport -> transportation: 90
# transportation -> transportation - warehouse: 90
# 85 transportation - warehouse
# transport -> transportation - warehouse: 90
# transportation -> transportation - warehouse: 90
# warehouse -> transportation - warehouse: 90
# 86 travel
# 87 warehouse
# warehouse -> transportation - warehouse: 90
# 88 website design
# design -> website design: 90
# 89 writer
# {'administration': 'human resources administration', 'customer service': 'customer service-call center', 'design': 'website design', 'ecommerce': 'e-commerce', 'health': 'health jobs, nutrition, beauty', 'marketing': 'marketing jobs pr', 'medical': 'medical services', 'other': 'other jobs', 'production': 'production work', 'research': 'science, lab, research and development', 'science': 'science, lab, research and development', 'transport': 'transportation - warehouse', 'transportation': 'transportation - warehouse', 'warehouse': 'transportation - warehouse'}

# %%
#for later use of the role dictionary, contain  it as pickle file

import pickle

a_file = open("roles.pkl", "wb")
pickle.dump(roles, a_file)
a_file.close()

# %% [markdown]
# ## LabelEndcoder
#
# After translation and matching, it is the label endcoding process. In order to build model, features may have to be endcoded. This method may not be very crucial since K-mode can easily deal with catagorical dataset. On the other hand, endcoding feature could possibly enchance the model or reduce calculation time. In addtion to echancement, labelling may help us for implementation in others algorithms.
#
# To use LabelEndcoder, we have to import the library from scikit-learn. Merging active and previous tables together is required as the model need to learn all possible data.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_label = pd.DataFrame(all_data, columns=['role_name','sub_role_name','province','company_name'])

lab_enc = LabelEncoder()
for column in df_label.columns:
    df_label[column] = lab_enc.fit_transform(df_label[column])
    pkl_file = column + "_LabelEncoder.pkl"
    with open(pkl_file, 'wb') as file:
        pickle.dump(lab_enc, file)

# %% [markdown]
# ## Modeling (KModes clustering)
#
# Everyone may heard about K-mean clustering. It is one of the most famous methods for unsupervised learning, specifically clustring model. However K-mean applies Euclidean distance for the purpose of creating clusters which is not quite effective for categorical data likes these dataset.
#
# Thus, the model should implement K-Modes clustering. This method measures similarity of categorical data and build clusters. The algorithm is useful and its library is provided in Python.

# %% [markdown]
# ### Training Model on Previous Job Post

# %%
previous['role_name'] = clean_role_name(previous['role_name'])

previous['sub_role_name'] = clean_role_name(previous['sub_role_name'])

a_file = open("roles.pkl", "rb")
roles = pickle.load(a_file)

previous['role_name'] = previous['role_name'].replace(roles)
previous['sub_role_name'] = previous['sub_role_name'].replace(roles)

print(previous.head(10))
#
previous_endc = pd.DataFrame(previous, columns=['role_name','sub_role_name','province','company_name'])

lab_enc = LabelEncoder()

for column in previous_endc.columns:
    pkl_file = column + "_LabelEncoder.pkl"
    with open(pkl_file, 'rb') as file:
        pickle_model = pickle.load(file)
    previous_endc[column] = pickle_model.transform(previous_endc[column])
    
km = KModes(n_clusters=80, init='Huang', n_init=5, verbose=1).fit(df)

kmodes_model = "job_kmodes_model.pkl"
with open(kmodes_model, 'wb') as file:
    pickle.dump(km, file)

y = km.predict(df)

previous['cluster'] = y

# %% [markdown]
# ### Prediction on Active Job Post

# %%
active['role_name'] = clean_role_name(active['role_name'])

active['sub_role_name'] = clean_role_name(active['sub_role_name'])

a_file = open("roles.pkl", "rb")
roles = pickle.load(a_file)

active['role_name'] = active['role_name'].replace(roles)
active['sub_role_name'] = active['sub_role_name'].replace(roles)

print(active.groupby('role_name')['job_id'].nunique())

active_enc = pd.DataFrame(active, columns=['role_name','sub_role_name','province','company_name'])

lab_enc = LabelEncoder()
for column in active_enc.columns:
    pkl_file = column + "_LabelEncoder.pkl"
    with open(pkl_file, 'rb') as file:
        pickle_model = pickle.load(file)
    active_enc[column] = pickle_model.transform(active_enc[column])

kmodes_model = "job_kmodes_model.pkl"
with open(kmodes_model, 'rb') as file:
    km = pickle.load(file)

y = km.predict(df)

active['cluster'] = y

# %% [markdown]
# ## Clustering Model Evaluation using Elbow curve
#
# For evaluation part, Elbow curve method is implemented. In cluster analysis, the elbow method is a heuristic used in determining the number of clusters in a data set. The method consists of plotting the explained variation as a function of the number of clusters, and picking the elbow of the curve as the number of clusters to use. The same method can be used to choose the number of parameters in other data-driven models, such as the number of principal components to describe a data set.

# %%
################################## Evaluation Part ############################################

import matplotlib.pyplot as plt

sse = []
for k in range(1,150):
    print('k = '+ str(k))
    kmodes = KModes(n_clusters=k)
    kmodes.fit(df)
    sse.append(kmodes.cost_)

plt.style.use("fivethirtyeight")
plt.plot(range(1,150),sse)
plt.xticks(range(1,150))
plt.xlabel("Clusters")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# ![title](img/EvaluateElbow.png)

# %% [markdown]
# ## Generating Recommendation

# %%
previous_cluster = previous[['job_id','role_name','sub_role_name','province','company_name']]
active_cluster = active[['job_id','role_name','sub_role_name','province','company_name']]

df = pd.merge(user,previous_cluster,how="left",left_on='job_id',right_on='job_id')

df.dropna(subset=['cluster'],inplace=True)
df['recommendation'] = ""

# %% [markdown]
# ## Gower distance
#
# Gower’s Distance can be used to measure how different two records are. The records may contain combination of logical, categorical, numerical or text data. The distance is always a number between 0 (identical) and 1 (maximally dissimilar). The metrics used for each data type are described below:
#
# - quantitative (interval): range-normalized Manhattan distance
# - ordinal: variable is first ranked, then Manhattan distance is used with a special adjustment for ties
# - nominal: variables of k categories are first converted into k binary columns and then the Dice coefficient is used

# %%
import gower

for ind in df.index:

    searching_previous = previous_cluster.loc[previous_cluster.job_id == df.job_id[ind]]
    searching_active = active_cluster.loc[active_cluster.cluster == df.cluster[ind]]

    searching = pd.concat([searching_previous,searching_active])
    first_row = gower.gower_matrix(searching)[0]
    values = []
    try:
        first_min = min(first_row[first_row != min(first_row)])
        second_min = min(first_row[(first_row != first_min) & (first_row != min(first_row))])
        res = searching[first_row == first_min]
        res2 = searching[first_row == second_min]
        values = list(res.job_id.values) + list(res2.job_id.values)
        print(values)

    except:
        try:
            samp_value = active_cluster['job_id'].loc[active_cluster['cluster'] == int(df['cluster'][ind])].sample(n=2,random_state=1,replace=True).values
            values = values + list(set(samp_value) - set(values))
        except:
            samp_value = active_cluster['job_id'].loc[active_cluster['cluster'] == int(df['cluster'][ind])].values
            values = values + list(set(samp_value) - set(values))
        print("no similar Job")
    print(values)
    df['recommendation'][ind] = values

recommendation = df[['user_id','recommendation']]
recommendation['recommendation'] = recommendation['recommendation'].str.strip('[]')
res = recommendation.groupby('user_id').agg({'recommendation': lambda x: ','.join(x) })

# %% [markdown]
# ## Result from Recommendation

# %%
results = pd.read_csv("Result.csv")

display(results.head())
# Out:
#    user_id                                     recommendation
# 0        0             54623, 25341,25351, 25467,27049, 27409
# 1        1  25792, 27184,30067, 30984,36584, 25439,26060, ...
# 2        3  25725, 26981,25368, 27051,25356, 25395,25372, ...
# 3        4  25430, 25800,27604, 30168,34247, 39366,28435, ...
# 4        5             25783, 27383,25756, 26196,25416, 25446

# %%
job_rec = [54623, 25341]

display(active.loc[active['job_id'].isin(job_rec)])

job_rec2 = [25792,27184]

display(active.loc[active['job_id'].isin(job_rec2)])
# Out:
#        job_id                                          job_title role_name  \
# 21      25341  พนักงานจัดเรียงสินค้า(Merchandise วิ่ง Big C บ...     sell
# 29303   54623  พนักงานขาย ประจำร้าน Loft @ ศูนย์การค้าพาราไดซ...     sell
#
#                  sub_role_name                  location   latitude  \
# 21     Staff in the shop / PC    กรุงเทพมหานคร(เขตบางนา)        NaN
# 29303  Staff in the shop / PC   เขตปทุมวัน กรุงเทพมหานคร  13.746739
#
#         longitude                                           salary  \
# 21            NaN                                    10,500-12,000
# 29303  100.531893  เงินเดือน + Commission + โบนัส + สวัสดิการอื่นๆ
#
#       company_name province
# 21          oiexhh  Bangkok
# 29303       7p93l6  Bangkok
#       job_id                                          job_title role_name  \
# 472    25792                    พนักงานขาย (ประจำโลตัสพระราม 2)     sell
# 1864   27184  **พนักงานแนะนำสินค้า บ.ทรู (ซิมเติมเงิน,แพ็คเก...     sell
#
#      sub_role_name                                           location  \
# 472        retail   กรุงเทพมหานคร(เขตบางขุนเทียน),กรุงเทพมหานคร(เข...
# 1864       retail   กรุงเทพมหานคร(เขตห้วยขวาง),กรุงเทพมหานคร(เขตดิ...
#
#       latitude  longitude         salary company_name province
# 472        NaN        NaN         10,000       89smlj  Bangkok
# 1864       NaN        NaN  12,500-15,000       hrqhp2  Bangkok

# %% [markdown]
# ## Flaws of the system and Future works

# %% [markdown]
# <font size="3">Of course, the system is not perfect. In stead, there are a lot of gap that may be fixed or looked after.
# &nbsp;
#  - first of all, the system prone to new kinds of career. If there is a new career that can not match to role dictionary, it will cause a problem. This can be fixed be checking and updating new career to the label encoder model and role dictionary.
# &nbsp;
#  - Clustering lacking of evaluation and could add more features. Adding more features will increase recommendation efficiency and possibility to deliver to right target.
# &nbsp;
#  - Finding matching by the Gower distance method takes long time to calculate. Although clustered datasets are built for this purpose, it still takes a lot of time to process. Threading and load balancing are suggested for tackling down this problem.
# </font>
